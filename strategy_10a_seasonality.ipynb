# %% [markdown]
# Seasonality experimentation

# %%
# strat_univ = ['BTCUSDT', 'ETHUSDT', 'ADAUSDT', 'BNBUSDT', 'XRPUSDT', 'DOTUSDT', 'MATICUSDT']

strat_univ = [
    'BTCUSDT', 'ETHUSDT', 'XRPUSDT', 'BCHUSDT', 'LTCUSDT', 'EOSUSDT', 'BNBUSDT',
    'XLMUSDT', 'TRXUSDT', 'ADAUSDT', 'XTZUSDT', 'LINKUSDT', 'ATOMUSDT',
    'NEOUSDT', 'MKRUSDT', 'DASHUSDT', 'ETCUSDT', 'USDCUSDT', 'ONTUSDT', 'VETUSDT',
    'DOGEUSDT', 'BATUSDT', 'ZECUSDT',
    'SNXUSDT', 'QTUMUSDT', 'TUSDUSDT', 'ZRXUSDT',
    'THXUSDT', 'THRUSDT', 'ALGOUSDT', 'REPUSDT', 'NANOUSDT', 'KBCUSDT', 'BTGUSDT', 'RVNUSDT', 'OMGUSDT',
    'CNXUSDT', 'ABBCUSDT', 'XINUSDT', 'VSYSUSDT', 'SEELEUSDT', 'EONUSDT', 'ZBUSDT', 'EKTUSDT', 'DGBUSDT',
    'BTMUSDT', 'LSKUSDT', 'KMDUSDT', 'SAIUSDT', 'LUNAUSDT', 'KCSUSDT', 'FTTUSDT', 'QNTUSDT', 'SXPUSDT',
    'BDXUSDT', 'GAPUSDT', 'BCDUSDT', 'THETAUSDT', 'ICXUSDT', 'FSTUSDT', 'MATICUSDT', 'SCUSDT', 'EVRUSDT',
    'BTTUSDT', 'MOFUSDT', 'IOSTUSDT', 'MCOUSDT', 'WAVESUSDT', 'XVGUSDT', 'MONAUSDT', 'BTSUSDT', 'BCNUSDT',
    'HCUSDT', 'MAIDUSDT', 'NEXOUSDT', 'ARDRUSDT', 'DXUSDT', 'OKBUSDT', 'FXCUSDT', 'RLCUSDT', 'MBUSDT',
    'BXKUSDT', 'AEUSDT', 'ENJUSDT', 'STEEMUSDT', 'SLVUSDT', 'BRZEUSDT', 'ZILUSDT', 'VESTUSDT', 'ZENUSDT',
    'SOLVEUSDT', 'CHZUSDT', 'NOAHUSDT', 'LAUSDT', 'BTMXUSDT', 'ETNUSDT', 'ENGUSDT', 'ILCUSDT', 'NPXSUSDT',
    'CRPTUSDT', 'GNTUSDT', 'SNTUSDT', 'ELFUSDT', 'JWLUSDT', 'FETUSDT', 'BOTXUSDT', 'NRGUSDT', 'DGDUSDT',
    'EXMRUSDT', 'EURSUSDT', 'AOAUSDT', 'RIFUSDT', 'CIX100USDT', 'BFUSDT', 'XZCUSDT', 'FABUSDT', 'GRINUSDT',
    'NETUSDT', 'VERIUSDT', 'DGTXUSDT', 'KNCUSDT', 'RENUSDT', 'STRATUSDT', 'ETPUSDT', 'NEXUSDT', 'NEWUSDT',
    'BCZEROUSDT', 'GXCUSDT', 'TNTUSDT', 'BTC2USDT', 'PPTUSDT', 'USDKUSDT', 'ELAUSDT', 'IGNISUSDT', 'PLCUSDT',
    'BNKUSDT', 'DTRUSDT', 'RCNUSDT', 'HPTUSDT', 'LAMBUSDT', 'MANAUSDT', 'EDCUSDT', 'BEAMUSDT', 'TTUSDT',
    'AIONUSDT', 'BZUSDT', 'WTCUSDT', 'WICCUSDT', 'LRCUSDT', 'BRDUSDT', 'FCTUSDT', 'NULSUSDT', 'FTMUSDT',
    'IOTXUSDT', 'QBITUSDT', 'XMXUSDT', 'YOUUSDT', 'NASUSDT', 'WAXPUSDT', 'ARKUSDT', 'RDDUSDT', 'GNYUSDT',
    'AGVCUSDT', 'HYNUSDT', 'CVCUSDT', 'WANUSDT', 'WINUSDT', 'LINAUSDT', 'RUSDT', 'PAIUSDT', 'FSNUSDT',
    'FUNUSDT', 'DPTUSDT', 'BHDUSDT', 'LOOMUSDT', 'XACUSDT', 'BUSDUSDT', 'BHPUSDT', 'TRUEUSDT', 'LOKIUSDT',
    'QASHUSDT', 'BNTUSDT', 'DOTUSDT', 'SOLUSDT']

# %% [markdown]
# # Load And Structure Data

# %%
from binance.client import Client as bnb_client
from binance.client import BinanceAPIException
from datetime import datetime
import pandas as pd

client = bnb_client(tld='US')

def get_price_data_for_coin(coin, freq, start_date):
    bn_data = client.get_historical_klines(coin, freq, start_date)
    columns = ['open_time','open','high','low','close','volume','close_time','quote_volume',
        'num_trades','taker_base_volume','taker_quote_volume','ignore']

    bn_data = pd.DataFrame(bn_data, columns=columns)
    bn_data['open_time'] = bn_data['open_time'].map(lambda x: datetime.utcfromtimestamp(x / 1000))
    bn_data['close_time'] = bn_data['close_time'].map(lambda x: datetime.utcfromtimestamp(x / 1000))
    return bn_data


def get_price_data_for_universe(freq, start_date):
    px_data = {}

    for coin in strat_univ:
        try:
            px_data[coin] = get_price_data_for_coin(coin, freq, start_date).set_index('open_time')
            print(f"Downloaded data for {coin}.")
        except BinanceAPIException:
            print(f"Couldn't load data for {coin}.")
    
    return px_data

# %%
data_freq = '4h'
look_back_window_size = 30 * 6
look_back_min_periods = 10 * 6
start_datetime = '2020-01-01 00:00:00'

# %%
px_data = get_price_data_for_universe(data_freq, start_datetime)
# Out:
# Downloaded data for BTCUSDT.
# Downloaded data for ETHUSDT.
# Downloaded data for XRPUSDT.
# Downloaded data for BCHUSDT.
# Downloaded data for LTCUSDT.
# Downloaded data for EOSUSDT.
# Downloaded data for BNBUSDT.
# Downloaded data for XLMUSDT.
# Downloaded data for TRXUSDT.
# Downloaded data for ADAUSDT.
# Downloaded data for XTZUSDT.
# Downloaded data for LINKUSDT.
# Downloaded data for ATOMUSDT.
# Downloaded data for NEOUSDT.
# Downloaded data for MKRUSDT.
# Downloaded data for DASHUSDT.
# Downloaded data for ETCUSDT.
# Downloaded data for USDCUSDT.
# Downloaded data for ONTUSDT.
# Downloaded data for VETUSDT.
# Downloaded data for DOGEUSDT.
# Downloaded data for BATUSDT.
# Downloaded data for ZECUSDT.
# Downloaded data for SNXUSDT.
# Downloaded data for QTUMUSDT.
# Downloaded data for TUSDUSDT.
# Downloaded data for ZRXUSDT.
# Couldn't load data for THXUSDT.
# Couldn't load data for THRUSDT.
# Downloaded data for ALGOUSDT.
# Couldn't load data for REPUSDT.
# Couldn't load data for NANOUSDT.
# Couldn't load data for KBCUSDT.
# Couldn't load data for BTGUSDT.
# Downloaded data for RVNUSDT.
# Downloaded data for OMGUSDT.
# Couldn't load data for CNXUSDT.
# Couldn't load data for ABBCUSDT.
# Couldn't load data for XINUSDT.
# Couldn't load data for VSYSUSDT.
# Couldn't load data for SEELEUSDT.
# Couldn't load data for EONUSDT.
# Couldn't load data for ZBUSDT.
# Couldn't load data for EKTUSDT.
# Downloaded data for DGBUSDT.
# Couldn't load data for BTMUSDT.
# Downloaded data for LSKUSDT.
# Couldn't load data for KMDUSDT.
# Couldn't load data for SAIUSDT.
# Couldn't load data for LUNAUSDT.
# Couldn't load data for KCSUSDT.
# Couldn't load data for FTTUSDT.
# Downloaded data for QNTUSDT.
# Couldn't load data for SXPUSDT.
# Couldn't load data for BDXUSDT.
# Couldn't load data for GAPUSDT.
# Couldn't load data for BCDUSDT.
# Downloaded data for THETAUSDT.
# Downloaded data for ICXUSDT.
# Couldn't load data for FSTUSDT.
# Downloaded data for MATICUSDT.
# Couldn't load data for SCUSDT.
# Couldn't load data for EVRUSDT.
# Couldn't load data for BTTUSDT.
# Couldn't load data for MOFUSDT.
# Downloaded data for IOSTUSDT.
# Couldn't load data for MCOUSDT.
# Downloaded data for WAVESUSDT.
# Couldn't load data for XVGUSDT.
# Couldn't load data for MONAUSDT.
# Couldn't load data for BTSUSDT.
# Couldn't load data for BCNUSDT.
# Couldn't load data for HCUSDT.
# Couldn't load data for MAIDUSDT.
# Couldn't load data for NEXOUSDT.
# Couldn't load data for ARDRUSDT.
# Couldn't load data for DXUSDT.
# Couldn't load data for OKBUSDT.
# Couldn't load data for FXCUSDT.
# Downloaded data for RLCUSDT.
# Couldn't load data for MBUSDT.
# Couldn't load data for BXKUSDT.
# Couldn't load data for AEUSDT.
# Downloaded data for ENJUSDT.
# Couldn't load data for STEEMUSDT.
# Couldn't load data for SLVUSDT.
# Couldn't load data for BRZEUSDT.
# Downloaded data for ZILUSDT.
# Couldn't load data for VESTUSDT.
# Downloaded data for ZENUSDT.
# Couldn't load data for SOLVEUSDT.
# Downloaded data for CHZUSDT.
# Couldn't load data for NOAHUSDT.
# Couldn't load data for LAUSDT.
# Couldn't load data for BTMXUSDT.
# Couldn't load data for ETNUSDT.
# Couldn't load data for ENGUSDT.
# Couldn't load data for ILCUSDT.
# Couldn't load data for NPXSUSDT.
# Couldn't load data for CRPTUSDT.
# Couldn't load data for GNTUSDT.
# Couldn't load data for SNTUSDT.
# Couldn't load data for ELFUSDT.
# Couldn't load data for JWLUSDT.
# Downloaded data for FETUSDT.
# Couldn't load data for BOTXUSDT.
# Couldn't load data for NRGUSDT.
# Couldn't load data for DGDUSDT.
# Couldn't load data for EXMRUSDT.
# Couldn't load data for EURSUSDT.
# Couldn't load data for AOAUSDT.
# Couldn't load data for RIFUSDT.
# Couldn't load data for CIX100USDT.
# Couldn't load data for BFUSDT.
# Couldn't load data for XZCUSDT.
# Couldn't load data for FABUSDT.
# Couldn't load data for GRINUSDT.
# Couldn't load data for NETUSDT.
# Couldn't load data for VERIUSDT.
# Couldn't load data for DGTXUSDT.
# Downloaded data for KNCUSDT.
# Downloaded data for RENUSDT.
# Couldn't load data for STRATUSDT.
# Couldn't load data for ETPUSDT.
# Couldn't load data for NEXUSDT.
# Couldn't load data for NEWUSDT.
# Couldn't load data for BCZEROUSDT.
# Couldn't load data for GXCUSDT.
# Couldn't load data for TNTUSDT.
# Couldn't load data for BTC2USDT.
# Couldn't load data for PPTUSDT.
# Couldn't load data for USDKUSDT.
# Couldn't load data for ELAUSDT.
# Couldn't load data for IGNISUSDT.
# Couldn't load data for PLCUSDT.
# Couldn't load data for BNKUSDT.
# Couldn't load data for DTRUSDT.
# Couldn't load data for RCNUSDT.
# Couldn't load data for HPTUSDT.
# Couldn't load data for LAMBUSDT.
# Downloaded data for MANAUSDT.
# Couldn't load data for EDCUSDT.
# Couldn't load data for BEAMUSDT.
# Couldn't load data for TTUSDT.
# Couldn't load data for AIONUSDT.
# Couldn't load data for BZUSDT.
# Couldn't load data for WTCUSDT.
# Couldn't load data for WICCUSDT.
# Downloaded data for LRCUSDT.
# Couldn't load data for BRDUSDT.
# Couldn't load data for FCTUSDT.
# Couldn't load data for NULSUSDT.
# Downloaded data for FTMUSDT.
# Downloaded data for IOTXUSDT.
# Couldn't load data for QBITUSDT.
# Couldn't load data for XMXUSDT.
# Couldn't load data for YOUUSDT.
# Couldn't load data for NASUSDT.
# Downloaded data for WAXPUSDT.
# Couldn't load data for ARKUSDT.
# Couldn't load data for RDDUSDT.
# Couldn't load data for GNYUSDT.
# Couldn't load data for AGVCUSDT.
# Couldn't load data for HYNUSDT.
# Couldn't load data for CVCUSDT.
# Couldn't load data for WANUSDT.
# Couldn't load data for WINUSDT.
# Couldn't load data for LINAUSDT.
# Couldn't load data for RUSDT.
# Couldn't load data for PAIUSDT.
# Couldn't load data for FSNUSDT.
# Couldn't load data for FUNUSDT.
# Couldn't load data for DPTUSDT.
# Couldn't load data for BHDUSDT.
# Downloaded data for LOOMUSDT.
# Couldn't load data for XACUSDT.
# Downloaded data for BUSDUSDT.
# Couldn't load data for BHPUSDT.
# Couldn't load data for TRUEUSDT.
# Couldn't load data for LOKIUSDT.
# Couldn't load data for QASHUSDT.
# Downloaded data for BNTUSDT.
# Downloaded data for DOTUSDT.
# Downloaded data for SOLUSDT.

# %%
px_data
# Out:
# {'BTCUSDT':                                open            high             low  \
#  open_time
#  2020-01-01 00:00:00   7180.46000000   7238.03000000   7175.62000000
#  2020-01-01 04:00:00   7226.19000000   7231.70000000   7196.20000000
#  2020-01-01 08:00:00   7209.50000000   7231.17000000   7181.17000000
#  2020-01-01 12:00:00   7193.32000000   7244.43000000   7193.32000000
#  2020-01-01 16:00:00   7237.54000000   7245.54000000   7215.51000000
#  ...                             ...             ...             ...
#  2025-02-28 20:00:00  84569.75000000  84827.97000000  83643.82000000
#  2025-03-01 00:00:00  84573.84000000  85585.44000000  83805.23000000
#  2023-04-18 12:00:00     25188.70000000 2023-04-18 15:59:59.999
#  2023-04-18 16:00:00     73894.50000000 2023-04-18 19:59:59.999
#  2023-04-18 20:00:00      5280.40000000 2023-04-18 23:59:59.999
#  2023-04-19 00:00:00     30215.40000000 2023-04-19 02:59:59.999
#
#                           quote_volume  num_trades  taker_base_volume  \
#  open_time
#  2022-04-01 00:00:00  1776136.67018400        3151  10764102.80000000
#  2022-04-01 04:00:00    26567.46881600          63    127547.70000000
#  2022-04-01 08:00:00     5404.59517800          28      4594.00000000
#  2022-04-01 12:00:00    67201.02438200          92    267378.30000000
#  2022-04-01 16:00:00    30518.77696300          64    282820.10000000
#  ...                               ...         ...                ...
#  2023-04-18 08:00:00     2879.08101800          12     38120.80000000
#  2023-04-18 12:00:00     1678.20829500          22      6519.00000000
#  2023-04-18 16:00:00     4904.14396600          16     16644.40000000
#  2023-04-18 20:00:00      351.16841000           5       900.00000000
#  2023-04-19 00:00:00     2019.94685800          17      1026.40000000
#
#                      taker_quote_volume ignore
#  open_time
#  2022-04-01 00:00:00    861433.48822100      0
#  2022-04-01 04:00:00      9286.49265100      0
#  2022-04-01 08:00:00       334.23149100      0
#  2022-04-01 12:00:00     19633.26177200      0
#  2022-04-01 16:00:00     20972.60725200      0
#  ...                                ...    ...
#  2023-04-18 08:00:00      2527.36337400      0
#  2023-04-18 12:00:00       434.23150600      0
#  2023-04-18 16:00:00      1106.07032500      0
#  2023-04-18 20:00:00        59.97600000      0
#  2023-04-19 00:00:00        68.60454800      0
#
#  [2298 rows x 11 columns],
#  'ADAUSDT':                            open        high         low       close  \
#  open_time
#  2020-01-01 00:00:00  0.03277000  0.03322000  0.03271000  0.03308000
#  2020-01-01 04:00:00  0.03304000  0.03324000  0.03287000  0.03320000
#  2020-01-01 08:00:00  0.03308000  0.03327000  0.03302000  0.03321000
#  2020-01-01 12:00:00  0.03321000  0.03364000  0.03320000  0.03357000
#  2020-01-01 16:00:00  0.03365000  0.03374000  0.03358000  0.03361000
#  ...                         ...         ...         ...         ...
#  2025-02-28 20:00:00  0.63280000  0.63530000  0.62510000  0.63360000
#  2025-03-01 00:00:00  0.63520000  0.65920000  0.62910000  0.64460000
#  2025-03-01 04:00:00  0.64680000  0.65450000  0.64000000  0.64000000
#  2025-03-01 08:00:00  0.64110000  0.64930000  0.63170000  0.63700000
#  2025-03-01 12:00:00  0.63620000  0.63740000  0.62960000  0.62960000
#
#                                volume              close_time    quote_volume  \
#  open_time
#  2020-01-01 00:00:00  102547.50000000 2020-01-01 03:59:59.999   3379.03394100
#  2020-01-01 04:00:00  123837.90000000 2020-01-01 07:59:59.999   4079.36070800
#  2020-01-01 08:00:00   16867.60000000 2020-01-01 11:59:59.999    558.91601400
#  2020-01-01 12:00:00   24119.60000000 2020-01-01 15:59:59.999    807.57388300
#  2020-01-01 16:00:00   25282.50000000 2020-01-01 19:59:59.999    850.76023900
#  ...                              ...                     ...             ...
#  2025-02-28 20:00:00   17467.00000000 2025-02-28 23:59:59.999  11018.11768000
#  2025-03-01 00:00:00  116563.50000000 2025-03-01 03:59:59.999  74848.50535000
#  2025-03-01 04:00:00   39933.70000000 2025-03-01 07:59:59.999  25946.36552000
#  2025-03-01 08:00:00   30118.80000000 2025-03-01 11:59:59.999  19342.74838000
#  2025-03-01 12:00:00   21317.90000000 2025-03-01 15:59:59.999  13496.39355000
#
#                       num_trades taker_base_volume taker_quote_volume ignore
#  open_time
#  
#  2025-03-01 12:00:00  1542.00000000  0.00510000 2025-03-01 15:59:59.999
#
#                       quote_volume  num_trades taker_base_volume  \
#  open_time
#  2020-08-20 12:00:00   43.31536850           3        0.06446000
#  2020-08-20 16:00:00  829.03745660           6        1.20092000
#  2020-08-20 20:00:00  523.78483290           3        0.00000000
#  2020-08-21 00:00:00  302.01572450           5        0.04993000
#  2020-08-21 04:00:00  299.12400000           1        0.45000000
#  ...                           ...         ...               ...
#  2025-02-28 20:00:00  222.17050000           3        0.10370000
#  2025-03-01 00:00:00   67.76960000           5        0.01260000
#  2025-03-01 04:00:00    0.00000000           0        0.00000000
#  2025-03-01 08:00:00    0.00000000           0        0.00000000
#  2025-03-01 12:00:00    7.86420000           1        0.00000000
#
#                      taker_quote_volume ignore
#  open_time
#  2020-08-20 12:00:00        43.31536850      0
#  2020-08-20 16:00:00       829.03745660      0
#  2020-08-20 20:00:00         0.00000000      0
#  2020-08-21 00:00:00        32.43452800      0
#  2020-08-21 04:00:00       299.12400000      0
#  ...                                ...    ...
#  2025-02-28 20:00:00       161.25350000      0
#  2025-03-01 00:00:00        19.78200000      0
#  2025-03-01 04:00:00         0.00000000      0
#  2025-03-01 08:00:00         0.00000000      0
#  2025-03-01 12:00:00         0.00000000      0
#
#  [9923 rows x 11 columns],
#  'DASHUSDT':                             open         high          low        close  \
#  open_time
#  2023-06-27 00:00:00  36.25000000  36.25000000  35.25000000  35.25000000
#  2023-06-27 04:00:00  35.25000000  35.25000000  35.25000000  35.25000000
# ...
#  ...                         ...               ...                ...    ...
#  2025-02-28 20:00:00           6     2292.00000000        70.12080000      0
#  2025-03-01 00:00:00           1    10606.00000000       328.67994000      0
#  2025-03-01 04:00:00           4     1021.00000000        29.74978000      0
#  2025-03-01 08:00:00           1       99.00000000         3.00168000      0
#  2025-03-01 12:00:00           0        0.00000000         0.00000000      0
#
#  [5982 rows x 11 columns],
#  'LOOMUSDT':                            open        high         low       close  \
#  open_time
#  2023-02-02 12:00:00  0.06500000  0.06508000  0.05301000  0.05315000
#  2023-02-02 16:00:00  0.05320000  0.05398000  0.05316000  0.05364000
#  2023-02-02 20:00:00  0.05340000  0.05361000  0.05311000  0.05315000
#  2023-02-03 00:00:00  0.05385000  0.05463000  0.05385000  0.05461000
#  2023-02-03 04:00:00  0.05459000  0.05485000  0.05412000  0.05433000
#  ...                         ...         ...         ...         ...
#  2025-02-28 20:00:00  0.04700000  0.04700000  0.04700000  0.04700000
#  2025-03-01 00:00:00  0.04700000  0.04700000  0.04700000  0.04700000
#  2025-03-01 04:00:00  0.04700000  0.04700000  0.04700000  0.04700000
#  2025-03-01 08:00:00  0.04700000  0.04700000  0.04700000  0.04700000
#  2025-03-01 12:00:00  0.04700000  0.04700000  0.04700000  0.04700000
#
#                                volume              close_time    quote_volume  \
#  open_time
#  2023-02-02 12:00:00  390248.00000000 2023-02-02 15:59:59.999  21123.90735000
#  2023-02-02 16:00:00  121298.00000000 2023-02-02 19:59:59.999   6500.77429000
#  2023-02-02 20:00:00   96768.00000000 2023-02-02 23:59:59.999   5158.93888000
#
#                              volume              close_time     quote_volume  \
#  open_time
#  2020-09-18 12:00:00  5938.63000000 2020-09-18 15:59:59.999   17568.00354200
#  2020-09-18 16:00:00  9460.39000000 2020-09-18 19:59:59.999   27523.68361800
#  2020-09-18 20:00:00  1170.88000000 2020-09-18 23:59:59.999    3635.93331200
#  2020-09-19 00:00:00  3186.39000000 2020-09-19 03:59:59.999   10012.39589800
#  2020-09-19 04:00:00   327.10000000 2020-09-19 07:59:59.999    1019.29030300
#  ...                            ...                     ...              ...
#  2025-02-28 20:00:00  1422.28700000 2025-02-28 23:59:59.999  207436.19366000
#  2025-03-01 00:00:00   982.29600000 2025-03-01 03:59:59.999  146124.93330000
#  2025-03-01 04:00:00   286.19700000 2025-03-01 07:59:59.999   41398.24324000
#  2025-03-01 08:00:00   214.36800000 2025-03-01 11:59:59.999   30140.31293000
#  2025-03-01 12:00:00    33.46300000 2025-03-01 15:59:59.999    4703.61401000
#
#                       num_trades taker_base_volume taker_quote_volume ignore
#  open_time
#  2020-09-18 12:00:00         133     4094.28000000     12121.60856500      0
#  2020-09-18 16:00:00         233     6386.82000000     18522.07640100      0
#  2020-09-18 20:00:00          57      886.01000000      2742.53900200      0
#  2020-09-19 00:00:00         119     2463.94000000      7682.38730400      0
#  2020-09-19 04:00:00          16      226.80000000       709.60025800      0
#  ...                         ...               ...                ...    ...
#  2025-02-28 20:00:00         165      998.22700000    145439.75021000      0
#  2025-03-01 00:00:00         326      561.94100000     83700.47629000      0
#  2025-03-01 04:00:00         135      104.12500000     15086.79656000      0
#  2025-03-01 08:00:00         113      157.78100000     22102.64897000      0
#  2025-03-01 12:00:00          23       13.64900000      1929.37869000      0
#
#  [9749 rows x 11 columns]}

# %%
px_close = {coin: px_data[coin]["close"] for coin in px_data}
px_close = pd.DataFrame(px_close).astype(float)
px_close.index.rename("datetime", inplace=True)

px_close
# Out:
#                       BTCUSDT  ETHUSDT  XRPUSDT  BCHUSDT  LTCUSDT  EOSUSDT  \
# datetime
# 2020-01-01 00:00:00   7230.71   130.18  0.19406   205.64    41.58      NaN
# 2020-01-01 04:00:00   7205.50   130.52  0.19518   206.72    41.55      NaN
# 2020-01-01 08:00:00   7195.80   130.84  0.19358   205.61    41.67      NaN
# 2020-01-01 12:00:00   7233.02   131.84  0.19428   206.63    41.89      NaN
# 2020-01-01 16:00:00   7223.72   131.98  0.19474   206.35    41.79      NaN
# ...                       ...      ...      ...      ...      ...      ...
# 2025-02-28 20:00:00  84253.48  2236.50  2.14820   314.90   128.11   0.5600
# 2025-03-01 00:00:00  85412.67  2262.00  2.19370   321.70   128.35   0.5600
# 2025-03-01 04:00:00  84798.57  2231.95  2.16950   313.20   126.22   0.5389
# 2025-03-01 08:00:00  84698.44  2183.12  2.16020   308.70   125.83   0.5597
# 2025-03-01 12:00:00  84418.84  2150.32  2.15110   308.70   123.81   0.5597
#
#                       BNBUSDT  XLMUSDT  TRXUSDT  ADAUSDT  ...  MANAUSDT  \
# datetime                                                  ...
# 2020-01-01 00:00:00   13.8159  0.04515      NaN  0.03308  ...       NaN
# 2020-01-01 04:00:00   13.7648  0.04493      NaN  0.03320  ...       NaN
# 2020-01-01 08:00:00   13.7162  0.04509      NaN  0.03321  ...       NaN
# 2020-01-01 12:00:00   13.7958  0.04542      NaN  0.03357  ...       NaN
# 2020-01-01 16:00:00   13.7270  0.04547      NaN  0.03361  ...       NaN
# ...                       ...      ...      ...      ...  ...       ...
# 2025-02-28 20:00:00  589.4500  0.28650      NaN  0.63360  ...    0.2895
# 2025-03-01 00:00:00  595.6900  0.29530      NaN  0.64460  ...    0.2941
# 2025-03-01 04:00:00  596.0000  0.29540      NaN  0.64000  ...    0.2920
# 2025-03-01 08:00:00  591.6000  0.30050      NaN  0.63700  ...    0.2850
# 2025-03-01 12:00:00  594.6100  0.30110      NaN  0.62960  ...    0.2830
#
#                      LRCUSDT  FTMUSDT  IOTXUSDT  WAXPUSDT  LOOMUSDT  BUSDUSDT  \
# datetime
# 2020-01-01 00:00:00      NaN      NaN       NaN       NaN       NaN       NaN
# 2020-01-01 04:00:00      NaN      NaN       NaN       NaN       NaN       NaN
# 2020-01-01 08:00:00      NaN      NaN       NaN       NaN       NaN       NaN
# 2020-01-01 12:00:00      NaN      NaN       NaN       NaN       NaN       NaN
# 2020-01-01 16:00:00      NaN      NaN       NaN       NaN       NaN       NaN
# ...                      ...      ...       ...       ...       ...       ...
# 2025-02-28 20:00:00   0.1229   0.6616   0.03744   0.03100     0.047       NaN
# 2025-03-01 00:00:00   0.1234   0.7218   0.03634   0.03099     0.047       NaN
# 2025-03-01 04:00:00   0.1200   0.7211   0.03567   0.02604     0.047       NaN
# 2025-03-01 08:00:00   0.1186   0.7103   0.03552   0.03032     0.047       NaN
# 2025-03-01 12:00:00   0.1186   0.7044   0.03552   0.03032     0.047       NaN
#
#                      BNTUSDT  DOTUSDT  SOLUSDT
# datetime
# 2020-01-01 00:00:00      NaN      NaN      NaN
# 2020-01-01 04:00:00      NaN      NaN      NaN
# 2020-01-01 08:00:00      NaN      NaN      NaN
# 2020-01-01 12:00:00      NaN      NaN      NaN
# 2020-01-01 16:00:00      NaN      NaN      NaN
# ...                      ...      ...      ...
# 2025-02-28 20:00:00    0.504    4.721   148.02
# 2025-03-01 00:00:00    0.504    4.734   145.64
# 2025-03-01 04:00:00    0.504    4.642   142.65
# 2025-03-01 08:00:00    0.504    4.566   140.62
# 2025-03-01 12:00:00    0.504    4.556   139.61
#
# [11314 rows x 56 columns]

# %%
(365 * 5 + 2) * 6 + 31 * 6 + 18 * 6 + 3
# Out:
# 11259

# %% [markdown]
# ###########################################################################

# %% [markdown]
# Comparison of consecutive returns per week:

# %%
df_4h_returns = px_close / px_close.shift() - 1
df_4h_returns
# Out:
#                       BTCUSDT   ETHUSDT   XRPUSDT   BCHUSDT   LTCUSDT  \
# datetime
# 2020-01-01 00:00:00       NaN       NaN       NaN       NaN       NaN
# 2020-01-01 04:00:00 -0.003487  0.002612  0.005771  0.005252 -0.000722
# 2020-01-01 08:00:00 -0.001346  0.002452 -0.008198 -0.005370  0.002888
# 2020-01-01 12:00:00  0.005172  0.007643  0.003616  0.004961  0.005280
# 2020-01-01 16:00:00 -0.001286  0.001062  0.002368 -0.001355 -0.002387
# ...                       ...       ...       ...       ...       ...
# 2025-02-28 20:00:00 -0.003759  0.002384 -0.000372 -0.002850  0.003918
# 2025-03-01 00:00:00  0.013758  0.011402  0.021181  0.021594  0.001873
# 2025-03-01 04:00:00 -0.007190 -0.013285 -0.011032 -0.026422 -0.016595
# 2025-03-01 08:00:00 -0.001181 -0.021878 -0.004287 -0.014368 -0.003090
# 2025-03-01 12:00:00 -0.003301 -0.015024 -0.004213  0.000000 -0.016053
#
#                       EOSUSDT   BNBUSDT   XLMUSDT  TRXUSDT   ADAUSDT  ...  \
# datetime                                                              ...
# 2020-01-01 00:00:00       NaN       NaN       NaN      NaN       NaN  ...
# 2020-01-01 04:00:00       NaN -0.003699 -0.004873      NaN  0.003628  ...
# 2020-01-01 08:00:00       NaN -0.003531  0.003561      NaN  0.000301  ...
# 2020-01-01 12:00:00       NaN  0.005803  0.007319      NaN  0.010840  ...
# 2020-01-01 16:00:00       NaN -0.004987  0.001101      NaN  0.001192  ...
# ...                       ...       ...       ...      ...       ...  ...
# 2025-02-28 20:00:00  0.000000  0.003268  0.001748      NaN -0.001733  ...
# 2025-03-01 00:00:00  0.000000  0.010586  0.030716      NaN  0.017361  ...
# 2025-03-01 04:00:00 -0.037679  0.000520  0.000339      NaN -0.007136  ...
# 2025-03-01 08:00:00  0.038597 -0.007383  0.017265      NaN -0.004687  ...
# 2025-03-01 12:00:00  0.000000  0.005088  0.001997      NaN -0.011617  ...
#
#                      MANAUSDT   LRCUSDT   FTMUSDT  IOTXUSDT  WAXPUSDT  \
# datetime
# 2020-01-01 00:00:00       NaN       NaN       NaN       NaN       NaN
# 2020-01-01 04:00:00       NaN       NaN       NaN       NaN       NaN
# 2020-01-01 08:00:00       NaN       NaN       NaN       NaN       NaN
# 2020-01-01 12:00:00       NaN       NaN       NaN       NaN       NaN
# 2020-01-01 16:00:00       NaN       NaN       NaN       NaN       NaN
# ...                       ...       ...       ...       ...       ...
# 2025-02-28 20:00:00 -0.024924  0.000000 -0.032324 -0.053829  0.118326
# 2025-03-01 00:00:00  0.015889  0.004068  0.090992 -0.029380 -0.000323
# 2025-03-01 04:00:00 -0.007140 -0.027553 -0.000970 -0.018437 -0.159729
# 2025-03-01 08:00:00 -0.023973 -0.011667 -0.014977 -0.004205  0.164363
# 2025-03-01 12:00:00 -0.007018  0.000000 -0.008306  0.000000  0.000000
#
#                      LOOMUSDT  BUSDUSDT  BNTUSDT   DOTUSDT   SOLUSDT
# datetime
# 2020-01-01 00:00:00       NaN       NaN      NaN       NaN       NaN
# 2020-01-01 04:00:00       NaN       NaN      NaN       NaN       NaN
# 2020-01-01 08:00:00       NaN       NaN      NaN       NaN       NaN
# 2020-01-01 12:00:00       NaN       NaN      NaN       NaN       NaN
# 2020-01-01 16:00:00       NaN       NaN      NaN       NaN       NaN
# ...                       ...       ...      ...       ...       ...
# 2025-02-28 20:00:00       0.0       NaN      0.0  0.001273  0.011066
# 2025-03-01 00:00:00       0.0       NaN      0.0  0.002754 -0.016079
# 2025-03-01 04:00:00       0.0       NaN      0.0 -0.019434 -0.020530
# 2025-03-01 08:00:00       0.0       NaN      0.0 -0.016372 -0.014231
# 2025-03-01 12:00:00       0.0       NaN      0.0 -0.002190 -0.007182
#
# [11314 rows x 56 columns]

# %%
def get_buy_info(sell_weekday, sell_hour, num_look_back_periods):
    time_in_week = sell_weekday * 24 + sell_hour
    time_in_week -= (num_look_back_periods * 4)
    while time_in_week < 0:
        time_in_week += 24 * 7
    return (time_in_week // 24, time_in_week % 24)


def get_holding_window_for_ticker(ticker, px_close_df, num_look_back_periods, period_start, period_end):
    px_close_period_df = px_close_df.loc[period_start:period_end]
    ticker_returns = px_close_period_df[ticker] / px_close_period_df[ticker].shift(num_look_back_periods) - 1
    ticker_returns_df = pd.DataFrame({
        "returns": ticker_returns,
        "weekday": ticker_returns.index.weekday,
        "hour": ticker_returns.index.hour
    })
    sell_weekday, sell_hour = ticker_returns_df.groupby(
        by=["weekday", "hour"]).mean()["returns"].sort_values(ascending=False).index[0]
    buy_weekday, buy_hour = get_buy_info(sell_weekday, sell_hour, num_look_back_periods)

    return ((buy_weekday, buy_hour), (sell_weekday, sell_hour))


period_start = px_close.index[0]
period_end = px_close.index[len(px_close)//2]
window_start, window_end = get_holding_window_for_ticker('BTCUSDT', px_close, 2, period_start, period_end)
print(window_start)
print()
print(window_end)
# Out:
# (2, 4)
#
# (2, 12)

# %%
from datetime import timedelta
import numpy as np

def get_sample_trade_outcomes(ticker, px_close_df, buy_time, sell_time, initial_cash, period_start,
                              period_end):
    holdings_df = pd.DataFrame(
        0.0, columns=["cash", ticker], index=px_close_df.loc[period_start:period_end].index)

    has_coin_holding = False
    strat_holdings_data = {ticker: [0.0], "cash": [initial_cash] }

    for time_index in holdings_df.index:
        for asset in strat_holdings_data:
            strat_holdings_data[asset].append(strat_holdings_data[asset][-1])

        backward_one_week = time_index - timedelta(weeks=1)
        forward_one_week = time_index + timedelta(weeks=1)

        if np.isnan(px_close_df.loc[time_index, ticker]):
            continue
        elif (forward_one_week in px_close_df.index) and \
            np.isnan(px_close_df.loc[forward_one_week, ticker]):
            continue
        elif (backward_one_week in px_close_df.index) and \
            np.isnan(px_close_df.loc[backward_one_week, ticker]):
            continue

        weekday = time_index.weekday()
        hour = time_index.hour

        if (weekday, hour) == buy_time:
            strat_holdings_data[ticker][-1] = strat_holdings_data["cash"][-1] / px_close_df.loc[time_index, ticker]
            strat_holdings_data["cash"][-1] = 0.0
        elif (weekday, hour) == sell_time:
            strat_holdings_data["cash"][-1] = strat_holdings_data[ticker][-1] * px_close_df.loc[time_index, ticker]
            strat_holdings_data[ticker][-1] = 0.0

    truncated_strat_holdings_data = {asset: res[1:] for (asset, res) in strat_holdings_data.items()}
    return pd.DataFrame(truncated_strat_holdings_data, index=holdings_df.index)


period_start = px_close.index[0]
period_end = px_close.index[len(px_close)//2]

strat_holdings = get_sample_trade_outcomes('BTCUSDT', px_close, window_start, window_end, 0.10,
                                           period_start, period_end)
strat_holdings
# Out:
#                       BTCUSDT      cash
# datetime
# 2020-01-01 00:00:00  0.000000  0.100000
# 2020-01-01 04:00:00  0.000014  0.000000
# 2020-01-01 08:00:00  0.000014  0.000000
# 2020-01-01 12:00:00  0.000000  0.100382
# 2020-01-01 16:00:00  0.000000  0.100382
# ...                       ...       ...
# 2022-08-01 00:00:00  0.000000  0.158867
# 2022-08-01 04:00:00  0.000000  0.158867
# 2022-08-01 08:00:00  0.000000  0.158867
# 2022-08-01 12:00:00  0.000000  0.158867
# 2022-08-01 16:00:00  0.000000  0.158867
#
# [5658 rows x 2 columns]

# %%
def get_net_returns(ticker, px_close_df, strat_holdings_df):
    value_from_stock = (px_close_df.loc[strat_holdings_df.index][ticker] * strat_holdings_df[ticker])
    value_from_cash = strat_holdings_df["cash"]

    total_value = value_from_stock + value_from_cash
    gross_ret = total_value / total_value.shift() - 1

    turnover = (strat_holdings_df[ticker].fillna(0) - strat_holdings_df[ticker].shift().fillna(0)).abs().sum()
    tcost_bps = 20
    return gross_ret.subtract(turnover * tcost_bps * 1e-4, fill_value=0)

net_returns = get_net_returns('BTCUSDT', px_close, strat_holdings)
net_returns.cumsum().plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Out:
# 1.0864831251403428

# %%
def get_max_sharpe_ratio_in_sample(ticker, px_close_df, period_start, period_end):
    max_sharpe_ratio = float('-inf')
    witnessing_net_returns = None
    witnessing_look_back_periods = None
    witnessing_initial_cash = None
    witnessing_buy_time = None
    witnessing_sell_time = None
    
    for num_look_back_periods in (1, 2, 3, 4, 5, 6, 12, 18):
        (buy_time, sell_time) = get_holding_window_for_ticker(
            ticker, px_close_df, num_look_back_periods, period_start, period_end)
        for initial_cash in (0.10, 0.50, 1.00, 5.00, 10.00, 50.00, 100.00):
            strat_holdings_df = get_sample_trade_outcomes(ticker, px_close_df, buy_time, sell_time,
                                                             initial_cash, period_start, period_end)
            net_returns = get_net_returns(ticker, px_close_df, strat_holdings_df)
            sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
            if sharpe_ratio > max_sharpe_ratio:
                max_sharpe_ratio = sharpe_ratio
                witnessing_net_returns = net_returns
                witnessing_look_back_periods = num_look_back_periods
                witnessing_initial_cash = initial_cash
                witnessing_buy_time = buy_time
                witnessing_sell_time = sell_time
    
    return {
        "max_sharpe_ratio": max_sharpe_ratio,
        "witnessing_net_returns": witnessing_net_returns,
        "witnessing_look_back_periods": witnessing_look_back_periods,
        "witnessing_initial_cash": witnessing_initial_cash,
        "witnessing_buy_time": witnessing_buy_time,
        "witnessing_sell_time": witnessing_sell_time,
    }

# %%
def get_outcome_in_sample(px_close_df):
    best_sharpe_ratios = dict()
    period_start = px_close_df.index[0]
    period_end = px_close_df.index[len(px_close)//2]
    for ticker in px_close_df.columns:
        best_sharpe_ratios[ticker] = get_max_sharpe_ratio_in_sample(
            ticker, px_close_df, period_start, period_end)
        print(f"Outcome calculated for ticker {ticker}.")
    return best_sharpe_ratios

# %%
best_sharpe_ratios = get_outcome_in_sample(px_close)
best_sharpe_ratios
# Out:
# Outcome calculated for ticker BTCUSDT.
# Outcome calculated for ticker ETHUSDT.
# Outcome calculated for ticker XRPUSDT.
# Outcome calculated for ticker BCHUSDT.
# Outcome calculated for ticker LTCUSDT.
# Outcome calculated for ticker EOSUSDT.
# Outcome calculated for ticker BNBUSDT.
# Outcome calculated for ticker XLMUSDT.
# Outcome calculated for ticker TRXUSDT.
# Outcome calculated for ticker ADAUSDT.
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Outcome calculated for ticker XTZUSDT.
# Outcome calculated for ticker LINKUSDT.
# Outcome calculated for ticker ATOMUSDT.
# Outcome calculated for ticker NEOUSDT.
# Outcome calculated for ticker MKRUSDT.
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Outcome calculated for ticker DASHUSDT.
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Outcome calculated for ticker ETCUSDT.
# Outcome calculated for ticker USDCUSDT.
# Outcome calculated for ticker ONTUSDT.
# Outcome calculated for ticker VETUSDT.
# Outcome calculated for ticker DOGEUSDT.
# Outcome calculated for ticker BATUSDT.
# Outcome calculated for ticker ZECUSDT.
# Outcome calculated for ticker SNXUSDT.
# Outcome calculated for ticker QTUMUSDT.
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Outcome calculated for ticker TUSDUSDT.
# Outcome calculated for ticker ZRXUSDT.
# Outcome calculated for ticker ALGOUSDT.
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Outcome calculated for ticker RVNUSDT.
# Outcome calculated for ticker OMGUSDT.
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Outcome calculated for ticker DGBUSDT.
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Outcome calculated for ticker LSKUSDT.
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Outcome calculated for ticker QNTUSDT.
# Outcome calculated for ticker THETAUSDT.
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Outcome calculated for ticker ICXUSDT.
# Outcome calculated for ticker MATICUSDT.
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Outcome calculated for ticker IOSTUSDT.
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Outcome calculated for ticker WAVESUSDT.
# Outcome calculated for ticker RLCUSDT.
# Outcome calculated for ticker ENJUSDT.
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Outcome calculated for ticker ZILUSDT.
# Outcome calculated for ticker ZENUSDT.
# Outcome calculated for ticker CHZUSDT.
# Outcome calculated for ticker FETUSDT.
# Outcome calculated for ticker KNCUSDT.
# Outcome calculated for ticker RENUSDT.
# Outcome calculated for ticker MANAUSDT.
# Outcome calculated for ticker LRCUSDT.
# Outcome calculated for ticker FTMUSDT.
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Outcome calculated for ticker IOTXUSDT.
# Outcome calculated for ticker WAXPUSDT.
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# /var/folders/46/nmm5hcbx71d6nqy2066wsyjc0000gn/T/ipykernel_1052/1802308742.py:16: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Outcome calculated for ticker LOOMUSDT.
# Outcome calculated for ticker BUSDUSDT.
# Outcome calculated for ticker BNTUSDT.
# Outcome calculated for ticker DOTUSDT.
# Outcome calculated for ticker SOLUSDT.
# {'BTCUSDT': {'max_sharpe_ratio': 1.4652890673974694,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.000004
#   2020-01-01 04:00:00   -0.003490
#   2020-01-01 08:00:00   -0.001350
#   2020-01-01 12:00:00    0.005169
#   2020-01-01 16:00:00   -0.001290
#                            ...
#   2022-08-01 00:00:00   -0.000004
#   2022-08-01 04:00:00   -0.000004
#   2022-08-01 08:00:00   -0.000004
#   2022-08-01 12:00:00   -0.000004
#   2022-08-01 16:00:00   -0.000004
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 4,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (2, 0),
#   'witnessing_sell_time': (2, 16)},
#  'ETHUSDT': {'max_sharpe_ratio': 0.4500472332073588,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.000118
#   2020-01-01 04:00:00    0.002493
#   2020-01-01 08:00:00    0.002333
#   2020-01-01 12:00:00    0.007525
#   2020-01-01 16:00:00    0.000944
#                            ...
#   2022-08-01 00:00:00   -0.000118
#   2022-08-01 04:00:00   -0.000118
#   2022-08-01 08:00:00   -0.000118
#   2022-08-01 12:00:00   -0.000118
#   2022-08-01 16:00:00   -0.000118
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 4,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (2, 0),
#   'witnessing_sell_time': (2, 16)},
#  'XRPUSDT': {'max_sharpe_ratio': -135.52352338322473,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.039166
#   2020-01-01 04:00:00   -0.039166
#   2020-01-01 08:00:00   -0.039166
#   2020-01-01 12:00:00   -0.039166
#   2020-01-01 16:00:00   -0.039166
#                            ...
#   2022-08-01 00:00:00   -0.039166
#   2022-08-01 04:00:00   -0.039166
#   2022-08-01 08:00:00   -0.039166
#   2022-08-01 12:00:00   -0.039166
#   2022-08-01 16:00:00   -0.039166
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 5,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (0, 8),
#   'witnessing_sell_time': (1, 4)},
#  'BCHUSDT': {'max_sharpe_ratio': -0.38792605192821733,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.000035
#   2020-01-01 04:00:00   -0.000035
#   2020-01-01 08:00:00   -0.000035
#   2020-01-01 12:00:00   -0.000035
#   2020-01-01 16:00:00   -0.000035
#                            ...
#   2022-08-01 00:00:00   -0.000035
#   2022-08-01 04:00:00   -0.000035
#   2022-08-01 08:00:00   -0.000035
#   2022-08-01 12:00:00   -0.000035
#   2022-08-01 16:00:00   -0.000035
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 6,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (0, 8),
#   'witnessing_sell_time': (1, 8)},
#  'LTCUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00   -1.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 12,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (0, 8),
#   'witnessing_sell_time': (2, 8)},
#  'EOSUSDT': {'max_sharpe_ratio': -54.78683835167955,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.008283
#   2020-01-01 04:00:00   -0.008283
#   2020-01-01 08:00:00   -0.008283
#   2020-01-01 12:00:00   -0.008283
#   2020-01-01 16:00:00   -0.008283
#                            ...
#   2022-08-01 00:00:00    0.005271
#   2022-08-01 04:00:00   -0.017199
#   2022-08-01 08:00:00   -0.022526
#   2022-08-01 12:00:00   -0.003721
#   2022-08-01 16:00:00   -0.071871
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (6, 16),
#   'witnessing_sell_time': (2, 16)},
#  'BNBUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00   -1.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 3,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (1, 16),
#   'witnessing_sell_time': (2, 4)},
#  'XLMUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00   -1.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 12,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (0, 16),
#   'witnessing_sell_time': (2, 16)},
#  'TRXUSDT': {'max_sharpe_ratio': -0.6221435254648535,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 1,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (3, 20),
#   'witnessing_sell_time': (4, 0)},
#  'ADAUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00   -1.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 12,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (0, 8),
#   'witnessing_sell_time': (2, 8)},
#  'XTZUSDT': {'max_sharpe_ratio': -inf,
#   'witnessing_net_returns': None,
#   'witnessing_look_back_periods': None,
#   'witnessing_initial_cash': None,
#   'witnessing_buy_time': None,
#   'witnessing_sell_time': None},
#  'LINKUSDT': {'max_sharpe_ratio': -7.608337083769774,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.001248
#   2020-01-01 04:00:00   -0.001248
#   2020-01-01 08:00:00   -0.001248
#   2020-01-01 12:00:00   -0.001248
#   2020-01-01 16:00:00   -0.001248
#                            ...
#   2022-08-01 00:00:00    0.009209
#   2022-08-01 04:00:00   -0.003836
#   2022-08-01 08:00:00   -0.016812
#   2022-08-01 12:00:00    0.014562
#   2022-08-01 16:00:00   -0.036268
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (5, 12),
#   'witnessing_sell_time': (1, 12)},
#  'ATOMUSDT': {'max_sharpe_ratio': -16.439127661613618,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.004609
#   2020-01-01 04:00:00   -0.004609
#   2020-01-01 08:00:00   -0.004609
#   2020-01-01 12:00:00   -0.004609
#   2020-01-01 16:00:00   -0.004609
#                            ...
#   2022-08-01 00:00:00   -0.004609
#   2022-08-01 04:00:00   -0.004609
#   2022-08-01 08:00:00   -0.004609
#   2022-08-01 12:00:00   -0.004609
#   2022-08-01 16:00:00   -0.004609
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 1,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (3, 8),
#   'witnessing_sell_time': (3, 12)},
#  'NEOUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00   -1.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 3,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (1, 16),
#   'witnessing_sell_time': (2, 4)},
#  'MKRUSDT': {'max_sharpe_ratio': 1.1020952640441768,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.000061
#   2020-01-01 04:00:00   -0.000061
#   2020-01-01 08:00:00   -0.000061
#   2020-01-01 12:00:00   -0.000061
#   2020-01-01 16:00:00   -0.000061
#                            ...
#   2022-08-01 00:00:00   -0.000061
#   2022-08-01 04:00:00   -0.000061
#   2022-08-01 08:00:00   -0.000061
#   2022-08-01 12:00:00   -0.000061
#   2022-08-01 16:00:00   -0.000061
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 5,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (4, 20),
#   'witnessing_sell_time': (5, 16)},
#  'DASHUSDT': {'max_sharpe_ratio': -inf,
#   'witnessing_net_returns': None,
#   'witnessing_look_back_periods': None,
#   'witnessing_initial_cash': None,
#   'witnessing_buy_time': None,
#   'witnessing_sell_time': None},
#  'ETCUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00   -1.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 3,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (1, 16),
#   'witnessing_sell_time': (2, 4)},
#  'USDCUSDT': {'max_sharpe_ratio': -4345.489894572399,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.012263
#   2020-01-01 04:00:00   -0.012263
#   2020-01-01 08:00:00   -0.012263
#   2020-01-01 12:00:00   -0.012263
#   2020-01-01 16:00:00   -0.012263
#                            ...
#   2022-08-01 00:00:00   -0.012263
#   2022-08-01 04:00:00   -0.012263
#   2022-08-01 08:00:00   -0.012163
#   2022-08-01 12:00:00   -0.012263
#   2022-08-01 16:00:00   -0.012063
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (0, 4),
#   'witnessing_sell_time': (3, 4)},
#  'ONTUSDT': {'max_sharpe_ratio': -0.6221435254648535,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 4,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (3, 8),
#   'witnessing_sell_time': (4, 0)},
#  'VETUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00   -1.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 5,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (1, 16),
#   'witnessing_sell_time': (2, 12)},
#  'DOGEUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (1, 0),
#   'witnessing_sell_time': (4, 0)},
#  'BATUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00   -1.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 5,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (1, 16),
#   'witnessing_sell_time': (2, 12)},
#  'ZECUSDT': {'max_sharpe_ratio': -0.30614750835391197,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.000123
#   2020-01-01 04:00:00   -0.000123
#   2020-01-01 08:00:00   -0.000123
#   2020-01-01 12:00:00   -0.000123
#   2020-01-01 16:00:00   -0.000123
#                            ...
#   2022-08-01 00:00:00   -0.000123
#   2022-08-01 04:00:00   -0.000123
#   2022-08-01 08:00:00   -0.000123
#   2022-08-01 12:00:00   -0.000123
#   2022-08-01 16:00:00   -0.000123
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (3, 8),
#   'witnessing_sell_time': (6, 8)},
#  'SNXUSDT': {'max_sharpe_ratio': -0.6221435254648535,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 3,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (1, 20),
#   'witnessing_sell_time': (2, 8)},
#  'QTUMUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00   -1.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 5,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (1, 16),
#   'witnessing_sell_time': (2, 12)},
#  'TUSDUSDT': {'max_sharpe_ratio': -inf,
#   'witnessing_net_returns': None,
#   'witnessing_look_back_periods': None,
#   'witnessing_initial_cash': None,
#   'witnessing_buy_time': None,
#   'witnessing_sell_time': None},
#  'ZRXUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (1, 12),
#   'witnessing_sell_time': (4, 12)},
#  'ALGOUSDT': {'max_sharpe_ratio': -130.98883582001022,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.019968
#   2020-01-01 04:00:00   -0.019968
#   2020-01-01 08:00:00   -0.019968
#   2020-01-01 12:00:00   -0.019968
#   2020-01-01 16:00:00   -0.019968
#                            ...
#   2022-08-01 00:00:00    0.002227
#   2022-08-01 04:00:00   -0.030532
#   2022-08-01 08:00:00   -0.012258
#   2022-08-01 12:00:00   -0.009962
#   2022-08-01 16:00:00   -0.049106
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (5, 8),
#   'witnessing_sell_time': (1, 8)},
#  'RVNUSDT': {'max_sharpe_ratio': -inf,
#   'witnessing_net_returns': None,
#   'witnessing_look_back_periods': None,
#   'witnessing_initial_cash': None,
#   'witnessing_buy_time': None,
#   'witnessing_sell_time': None},
#  'OMGUSDT': {'max_sharpe_ratio': -0.6221435254648535,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 12,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (3, 0),
#   'witnessing_sell_time': (5, 0)},
#  'DGBUSDT': {'max_sharpe_ratio': -inf,
#   'witnessing_net_returns': None,
#   'witnessing_look_back_periods': None,
#   'witnessing_initial_cash': None,
#   'witnessing_buy_time': None,
#   'witnessing_sell_time': None},
#  'LSKUSDT': {'max_sharpe_ratio': -inf,
#   'witnessing_net_returns': None,
#   'witnessing_look_back_periods': None,
#   'witnessing_initial_cash': None,
#   'witnessing_buy_time': None,
#   'witnessing_sell_time': None},
#  'QNTUSDT': {'max_sharpe_ratio': -inf,
#   'witnessing_net_returns': None,
#   'witnessing_look_back_periods': None,
#   'witnessing_initial_cash': None,
#   'witnessing_buy_time': None,
#   'witnessing_sell_time': None},
#  'THETAUSDT': {'max_sharpe_ratio': -35.306023969845235,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.003638
#   2020-01-01 04:00:00   -0.003638
#   2020-01-01 08:00:00   -0.003638
#   2020-01-01 12:00:00   -0.003638
#   2020-01-01 16:00:00   -0.003638
#                            ...
#   2022-08-01 00:00:00   -0.003638
#   2022-08-01 04:00:00   -0.003638
#   2022-08-01 08:00:00   -0.003638
#   2022-08-01 12:00:00   -0.003638
#   2022-08-01 16:00:00   -0.003638
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (3, 8),
#   'witnessing_sell_time': (6, 8)},
#  'ICXUSDT': {'max_sharpe_ratio': -inf,
#   'witnessing_net_returns': None,
#   'witnessing_look_back_periods': None,
#   'witnessing_initial_cash': None,
#   'witnessing_buy_time': None,
#   'witnessing_sell_time': None},
#  'MATICUSDT': {'max_sharpe_ratio': -0.6221435254648535,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (1, 0),
#   'witnessing_sell_time': (4, 0)},
#  'IOSTUSDT': {'max_sharpe_ratio': -inf,
#   'witnessing_net_returns': None,
#   'witnessing_look_back_periods': None,
#   'witnessing_initial_cash': None,
#   'witnessing_buy_time': None,
#   'witnessing_sell_time': None},
#  'WAVESUSDT': {'max_sharpe_ratio': -inf,
#   'witnessing_net_returns': None,
#   'witnessing_look_back_periods': None,
#   'witnessing_initial_cash': None,
#   'witnessing_buy_time': None,
#   'witnessing_sell_time': None},
#  'RLCUSDT': {'max_sharpe_ratio': -31.22544446388483,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.005346
#   2020-01-01 04:00:00   -0.005346
#   2020-01-01 08:00:00   -0.005346
#   2020-01-01 12:00:00   -0.005346
#   2020-01-01 16:00:00   -0.005346
#                            ...
#   2022-08-01 00:00:00   -0.005346
#   2022-08-01 04:00:00   -0.005346
#   2022-08-01 08:00:00   -0.005346
#   2022-08-01 12:00:00   -0.005346
#   2022-08-01 16:00:00   -0.005346
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (2, 16),
#   'witnessing_sell_time': (5, 16)},
#  'ENJUSDT': {'max_sharpe_ratio': -69.48897492452859,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.011572
#   2020-01-01 04:00:00   -0.011572
#   2020-01-01 08:00:00   -0.011572
#   2020-01-01 12:00:00   -0.011572
#   2020-01-01 16:00:00   -0.011572
#                            ...
#   2022-08-01 00:00:00    0.004662
#   2022-08-01 04:00:00   -0.017962
#   2022-08-01 08:00:00   -0.011572
#   2022-08-01 12:00:00    0.044698
#   2022-08-01 16:00:00   -0.045057
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (5, 8),
#   'witnessing_sell_time': (1, 8)},
#  'ZILUSDT': {'max_sharpe_ratio': -inf,
#   'witnessing_net_returns': None,
#   'witnessing_look_back_periods': None,
#   'witnessing_initial_cash': None,
#   'witnessing_buy_time': None,
#   'witnessing_sell_time': None},
#  'ZENUSDT': {'max_sharpe_ratio': -0.6221435254648535,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 12,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (3, 0),
#   'witnessing_sell_time': (5, 0)},
#  'CHZUSDT': {'max_sharpe_ratio': -534.0901688148351,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.07495
#   2020-01-01 04:00:00   -0.07495
#   2020-01-01 08:00:00   -0.07495
#   2020-01-01 12:00:00   -0.07495
#   2020-01-01 16:00:00   -0.07495
#                           ...
#   2022-08-01 00:00:00   -0.07495
#   2022-08-01 04:00:00   -0.07495
#   2022-08-01 08:00:00   -0.07495
#   2022-08-01 12:00:00   -0.07495
#   2022-08-01 16:00:00   -0.07495
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (3, 16),
#   'witnessing_sell_time': (6, 16)},
#  'FETUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (3, 8),
#   'witnessing_sell_time': (6, 8)},
#  'KNCUSDT': {'max_sharpe_ratio': -0.6221435254648534,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (1, 16),
#   'witnessing_sell_time': (4, 16)},
#  'RENUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 12,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (2, 8),
#   'witnessing_sell_time': (4, 8)},
#  'MANAUSDT': {'max_sharpe_ratio': -26.071728263765106,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.005531
#   2020-01-01 04:00:00   -0.005531
#   2020-01-01 08:00:00   -0.005531
#   2020-01-01 12:00:00   -0.005531
#   2020-01-01 16:00:00   -0.005531
#                            ...
#   2022-08-01 00:00:00   -0.005531
#   2022-08-01 04:00:00   -0.005531
#   2022-08-01 08:00:00   -0.005531
#   2022-08-01 12:00:00   -0.005531
#   2022-08-01 16:00:00   -0.005531
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (3, 8),
#   'witnessing_sell_time': (6, 8)},
#  'LRCUSDT': {'max_sharpe_ratio': -0.6221435254648534,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 4,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (1, 16),
#   'witnessing_sell_time': (2, 8)},
#  'FTMUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 6,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (3, 8),
#   'witnessing_sell_time': (4, 8)},
#  'IOTXUSDT': {'max_sharpe_ratio': -inf,
#   'witnessing_net_returns': None,
#   'witnessing_look_back_periods': None,
#   'witnessing_initial_cash': None,
#   'witnessing_buy_time': None,
#   'witnessing_sell_time': None},
#  'WAXPUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 12,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (2, 8),
#   'witnessing_sell_time': (4, 8)},
#  'LOOMUSDT': {'max_sharpe_ratio': -inf,
#   'witnessing_net_returns': None,
#   'witnessing_look_back_periods': None,
#   'witnessing_initial_cash': None,
#   'witnessing_buy_time': None,
#   'witnessing_sell_time': None},
#  'BUSDUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 5,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (6, 20),
#   'witnessing_sell_time': (0, 16)},
#  'BNTUSDT': {'max_sharpe_ratio': -59.91279124864594,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.006248
#   2020-01-01 04:00:00   -0.006248
#   2020-01-01 08:00:00   -0.006248
#   2020-01-01 12:00:00   -0.006248
#   2020-01-01 16:00:00   -0.006248
#                            ...
#   2022-08-01 00:00:00   -0.006248
#   2022-08-01 04:00:00   -0.006248
#   2022-08-01 08:00:00   -0.006248
#   2022-08-01 12:00:00   -0.006248
#   2022-08-01 16:00:00   -0.006248
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (3, 12),
#   'witnessing_sell_time': (6, 12)},
#  'DOTUSDT': {'max_sharpe_ratio': -0.6221435254648536,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00    0.0
#   2020-01-01 04:00:00    0.0
#   2020-01-01 08:00:00    0.0
#   2020-01-01 12:00:00    0.0
#   2020-01-01 16:00:00    0.0
#                         ...
#   2022-08-01 00:00:00    0.0
#   2022-08-01 04:00:00    0.0
#   2022-08-01 08:00:00    0.0
#   2022-08-01 12:00:00    0.0
#   2022-08-01 16:00:00    0.0
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (3, 8),
#   'witnessing_sell_time': (6, 8)},
#  'SOLUSDT': {'max_sharpe_ratio': -10.781314311241301,
#   'witnessing_net_returns': datetime
#   2020-01-01 00:00:00   -0.005065
#   2020-01-01 04:00:00   -0.005065
#   2020-01-01 08:00:00   -0.005065
#   2020-01-01 12:00:00   -0.005065
#   2020-01-01 16:00:00   -0.005065
#                            ...
#   2022-08-01 00:00:00   -0.005065
#   2022-08-01 04:00:00   -0.005065
#   2022-08-01 08:00:00   -0.005065
#   2022-08-01 12:00:00   -0.005065
#   2022-08-01 16:00:00   -0.005065
#   Length: 5658, dtype: float64,
#   'witnessing_look_back_periods': 18,
#   'witnessing_initial_cash': 0.1,
#   'witnessing_buy_time': (5, 4),
#   'witnessing_sell_time': (1, 4)}}

# %%
best_sharpe_ratios['BTCUSDT']['witnessing_net_returns'].cumsum().plot()
# Out:
# <Axes: xlabel='datetime'>

# %% [markdown]
# Only BTCUSDT and ETHUSDT have positive sharpe ratios. We therefore only use those.

# %%
witnessing_net_returns_data = dict()

# for ticker in best_sharpe_ratios:
for ticker in best_sharpe_ratios:
    if best_sharpe_ratios[ticker]['max_sharpe_ratio'] > 0:
        witnessing_net_returns_data[ticker] = best_sharpe_ratios[ticker]['witnessing_net_returns']

all_coin_strat_net_returns = pd.DataFrame(witnessing_net_returns_data)
wgt = np.linalg.inv(all_coin_strat_net_returns.cov()) @ all_coin_strat_net_returns.mean()
wgt = wgt / np.abs(wgt).sum()

combo = (all_coin_strat_net_returns * wgt).sum(1)
combo
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# datetime
# 2020-01-01 00:00:00    0.000023
# 2020-01-01 04:00:00   -0.002754
# 2020-01-01 08:00:00   -0.001455
# 2020-01-01 12:00:00    0.000908
# 2020-01-01 16:00:00   -0.001029
#                          ...
# 2022-08-01 00:00:00    0.000023
# 2022-08-01 04:00:00    0.000023
# 2022-08-01 08:00:00    0.000023
# 2022-08-01 12:00:00    0.000023
# 2022-08-01 16:00:00    0.000023
# Length: 5658, dtype: float64

# %%
combo.mean()
# Out:
# 9.755895025166004e-05

# %%
combo.std()
# Out:
# 0.0021277754784019567

# %%
combo.mean() / combo.std() * np.sqrt(365 * 6)
# Out:
# 2.145672210302468

# %%
def get_outcome_out_sample(px_close_df, best_in_sample_sharpe_ratios, strategy_weights):
    period_start = px_close_df.index[len(px_close)//2+1]
    period_end = px_close_df.index[-1]
    ticker_to_sharpe_data = dict()
    ticker_to_net_returns_data = dict()
    
    for ticker in best_in_sample_sharpe_ratios:
        if best_in_sample_sharpe_ratios[ticker]['max_sharpe_ratio'] > 0:
        
            strat_holdings_df = get_sample_trade_outcomes(
                ticker,
                px_close_df,
                best_in_sample_sharpe_ratios[ticker]["witnessing_buy_time"],
                best_in_sample_sharpe_ratios[ticker]["witnessing_sell_time"],
                best_in_sample_sharpe_ratios[ticker]["witnessing_initial_cash"],
                period_start,
                period_end)
            net_returns = get_net_returns(ticker, px_close_df, strat_holdings_df)
            sharpe_ratio = net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
        
            ticker_to_sharpe_data[ticker] = sharpe_ratio
            ticker_to_net_returns_data[ticker] = net_returns

            print(f"Out-sample outcome calculated for ticker {ticker}.")

    all_net_returns_df = pd.DataFrame(ticker_to_net_returns_data)
    combo = (all_net_returns_df * strategy_weights).sum(1)
    return all_net_returns_df, combo

# %%
out_sample_all_net_returns, out_sample_combo = get_outcome_out_sample(px_close, best_sharpe_ratios, wgt)
# Out:
# Out-sample outcome calculated for ticker BTCUSDT.
# Out-sample outcome calculated for ticker ETHUSDT.
# Out-sample outcome calculated for ticker MKRUSDT.

# %%
out_sample_combo.cumsum().plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
out_sample_combo.mean() / out_sample_combo.std() * np.sqrt(365 * 6)
# Out:
# 0.12755991563071703

# %%
out_sample_all_net_returns
# Out:
#                       BTCUSDT   ETHUSDT   MKRUSDT
# datetime
# 2022-08-01 20:00:00 -0.000002 -0.000027 -0.000044
# 2022-08-02 00:00:00 -0.000002 -0.000027 -0.000044
# 2022-08-02 04:00:00 -0.000002 -0.000027 -0.000044
# 2022-08-02 08:00:00 -0.000002 -0.000027 -0.000044
# 2022-08-02 12:00:00 -0.000002 -0.000027 -0.000044
# ...                       ...       ...       ...
# 2025-02-28 20:00:00 -0.000002 -0.000027 -0.000044
# 2025-03-01 00:00:00 -0.000002 -0.000027 -0.011620
# 2025-03-01 04:00:00 -0.000002 -0.000027 -0.000044
# 2025-03-01 08:00:00 -0.000002 -0.000027 -0.000044
# 2025-03-01 12:00:00 -0.000002 -0.000027  0.003209
#
# [5656 rows x 3 columns]

# %%
px_close.drop(['BTCUSDT','ETHUSDT','BNBUSDT'], axis=1).iloc[0:(len(px_close)//2)].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
px_close.loc[pd.to_datetime("2022-07-30 12:00:00")]
# Out:
# BTCUSDT      24526.22000
# ETHUSDT       1736.41000
# ADAUSDT          0.54623
# BNBUSDT        299.03540
# XRPUSDT              NaN
# DOTUSDT          8.67000
# MATICUSDT        0.97400
# Name: 2022-07-30 12:00:00, dtype: float64

# %%
interval_4h_returns, interval_4h_std = get_interval_returns(df_4h_returns)
interval_4h_returns
# Out:
#                  BTCUSDT   ETHUSDT   ADAUSDT   BNBUSDT   XRPUSDT   DOTUSDT  \
# weekday   hour
# Monday    0    -0.000790 -0.002504 -0.001889 -0.002643 -0.000723 -0.003789
#           4     0.001116  0.001835  0.002104  0.001469 -0.000498 -0.000208
#           8    -0.000908 -0.000712 -0.002506  0.000257 -0.000072 -0.001965
#           12    0.002928  0.003118  0.001695  0.001140  0.005511  0.001495
#           16    0.000175  0.000214  0.000498 -0.000340  0.005048 -0.001098
#           20    0.002366  0.003667  0.002069  0.002012  0.002407  0.002877
# Tuesday   0     0.000076 -0.001316  0.000672  0.000742 -0.000782 -0.000851
#           4     0.000692  0.001171  0.002521  0.001984 -0.001411  0.000129
#           8     0.000603  0.000982  0.000200  0.001035  0.000134  0.000374
#           12   -0.001196 -0.002335 -0.002028 -0.001238 -0.003297 -0.003572
#           16    0.000183  0.000007 -0.001028 -0.000259  0.004110 -0.002198
#           20    0.001324  0.000806  0.001903  0.002297 -0.000694  0.000850
# Wednesday 0     0.000052  0.000437 -0.000727  0.000541 -0.001525 -0.000909
#           4     0.000868  0.000971  0.002252  0.002277 -0.001021  0.000878
#           8     0.001194  0.000883  0.000757  0.000761  0.002019  0.000691
#           12    0.001403  0.000966  0.000652 -0.000567 -0.000027 -0.000998
#           16    0.000405  0.001590  0.001550  0.001030  0.001979  0.000561
#           20    0.000928  0.000994  0.001493  0.000978  0.000790 -0.000405
# Thursday  0    -0.000784 -0.000717 -0.000622 -0.000992 -0.000414 -0.001005
#           4     0.000556  0.000658  0.001664  0.001619 -0.002620  0.000448
#           8    -0.000107 -0.000124 -0.000484  0.000555  0.001298  0.000007
#           12    0.000733  0.001499  0.000465  0.000595  0.000667 -0.001122
#           16   -0.000563 -0.000171 -0.000636 -0.001714  0.000147 -0.001220
#           20   -0.001010 -0.001517 -0.000707 -0.000022  0.001809 -0.001198
# Friday    0    -0.000259  0.000680  0.001415  0.000856  0.000593  0.001605
#           4    -0.000642 -0.000754 -0.000014  0.000466 -0.001809 -0.000590
#           8     0.001950  0.001510  0.002783  0.001556  0.004708  0.003303
#           12   -0.000222 -0.000155 -0.000512 -0.000141 -0.002292 -0.000438
#           16    0.000075  0.000151 -0.000387  0.000623  0.002229 -0.001839
#           20    0.001003  0.000652  0.001761  0.001400  0.000950  0.000994
# Saturday  0     0.000402  0.001470  0.003392  0.001199  0.002145  0.002239
#           4    -0.000831 -0.000511  0.000458  0.000709  0.001782  0.000301
#           8    -0.000083 -0.000448  0.000946  0.000952  0.001220  0.000345
#           12    0.001227  0.001809  0.001449  0.000201  0.003411  0.000533
#           16    0.000186  0.000330 -0.000284 -0.001023  0.000182  0.001029
#           20   -0.000009  0.000711  0.001653  0.000642 -0.000951  0.000463
# Sunday    0    -0.000338 -0.000850 -0.000922 -0.000359 -0.000168 -0.000048
#           4     0.000794  0.001464  0.002749  0.001784  0.001140  0.000731
#           8    -0.000265 -0.000493 -0.000698  0.000331 -0.003128  0.000448
#           12   -0.001033 -0.000576 -0.002537 -0.001151 -0.000517 -0.000601
#           16    0.000327  0.000854  0.000129  0.000858 -0.000004  0.001197
#           20    0.000942  0.001275  0.000036  0.000735 -0.002338 -0.002278
#
#                 MATICUSDT
# weekday   hour
# Monday    0     -0.003282
#           4      0.000737
#           8     -0.001764
#           12     0.002162
#           16    -0.000467
#           20     0.002771
# Tuesday   0      0.000509
#           4      0.000684
#           8      0.000205
#           12    -0.004397
#           16    -0.002066
#           20     0.002000
# Wednesday 0     -0.000579
#           4      0.000178
#           8      0.001246
#           12    -0.002238
#           16    -0.001117
#           20     0.001784
# Thursday  0     -0.000609
#           4      0.001125
#           8     -0.000031
#           12     0.000624
#           16    -0.001062
#           20    -0.000640
# Friday    0      0.003256
#           4     -0.000658
#           8      0.000266
#           12    -0.002102
#           16     0.000527
#           20     0.001353
# Saturday  0      0.001973
#           4      0.001315
#           8     -0.003185
#           12     0.001306
#           16    -0.002191
#           20     0.001071
# Sunday    0     -0.001155
#           4      0.001014
#           8      0.000996
#           12    -0.000801
#           16     0.000543
#           20    -0.001948

# %%
pd.concat([interval_4h_returns["BTCUSDT"].sort_values(ascending=False).iloc[:5],
           interval_4h_returns["BTCUSDT"].sort_values(ascending=False).iloc[-5:]])
# Out:
# weekday    hour
# Monday     12      0.002928
#            20      0.002366
# Friday     8       0.001950
# Wednesday  12      0.001403
# Tuesday    20      0.001324
# Saturday   4      -0.000831
# Monday     8      -0.000905
# Thursday   20     -0.001010
# Sunday     12     -0.001012
# Tuesday    12     -0.001196
# Name: BTCUSDT, dtype: float64

# %%
interval_4h_returns["ETHUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday    hour
# Monday     20      0.003667
#            12      0.003118
#            4       0.001835
# Saturday   12      0.001809
# Wednesday  16      0.001590
# Name: ETHUSDT, dtype: float64

# %%
interval_4h_returns["ADAUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday    hour
# Saturday   0       0.003392
# Friday     8       0.002783
# Sunday     4       0.002749
# Tuesday    4       0.002521
# Wednesday  4       0.002252
# Name: ADAUSDT, dtype: float64

# %%
interval_4h_returns["BNBUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday    hour
# Tuesday    20      0.002297
# Wednesday  4       0.002277
# Monday     20      0.002012
# Tuesday    4       0.001984
# Sunday     4       0.001784
# Name: BNBUSDT, dtype: float64

# %%
interval_4h_returns["XRPUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday   hour
# Monday    12      0.005511
#           16      0.005048
# Friday    8       0.004708
# Tuesday   16      0.004110
# Saturday  12      0.003411
# Name: XRPUSDT, dtype: float64

# %%
df_8h_returns = px_close / px_close.shift(2) - 1
interval_8h_returns, interval_8h_std = get_interval_returns(df_8h_returns)
interval_8h_returns
# Out:
#                  BTCUSDT   ETHUSDT   ADAUSDT   BNBUSDT   XRPUSDT   DOTUSDT  \
# weekday   hour
# Monday    0     0.000175 -0.001091 -0.001739 -0.001835 -0.002913 -0.005909
#           4     0.000347 -0.000553  0.000281 -0.001086 -0.001034 -0.003886
#           8     0.000264  0.001240 -0.000329  0.001832 -0.000483 -0.002129
#           12    0.001969  0.002413 -0.000887  0.001380  0.005347 -0.000484
#           16    0.003061  0.003281  0.002126  0.000768  0.010599  0.000389
#           20    0.002536  0.003906  0.002584  0.001682  0.007432  0.001762
# Tuesday   0     0.002451  0.002330  0.002742  0.002729  0.001766  0.002030
#           4     0.000688 -0.000210  0.003075  0.002617 -0.002223 -0.000679
#           8     0.001393  0.002262  0.002816  0.003138 -0.001442  0.000462
#           12   -0.000648 -0.001505 -0.001962 -0.000346 -0.003238 -0.003232
#           16   -0.001030 -0.002401 -0.003073 -0.001588  0.000653 -0.005756
#           20    0.001450  0.000700  0.000815  0.001964  0.003339 -0.001394
# Wednesday 0     0.001366  0.001222  0.001179  0.002838 -0.002190 -0.000103
#           4     0.000930  0.001419  0.001556  0.002921 -0.002583 -0.000066
#           8     0.002068  0.001875  0.002999  0.002990  0.001060  0.001557
#           12    0.002613  0.001851  0.001411  0.000214  0.002064 -0.000291
#           16    0.001780  0.002527  0.002133  0.000449  0.001930 -0.000476
#           20    0.001357  0.002671  0.003089  0.002019  0.002898  0.000260
# Thursday  0     0.000125  0.000218  0.000797 -0.000073  0.000293 -0.001426
#           4    -0.000210 -0.000011  0.001306  0.000704 -0.002783 -0.000559
#           8     0.000493  0.000624  0.001300  0.002256 -0.001192  0.000485
#           12    0.000626  0.001338 -0.000276  0.001016  0.001539 -0.001130
#           16    0.000192  0.001335 -0.000111 -0.001124  0.000846 -0.002292
#           20   -0.001574 -0.001678 -0.001292 -0.001736  0.001813 -0.002396
# Friday    0    -0.001329 -0.000969  0.000591  0.000895  0.002372  0.000392
#           4    -0.000898 -0.000074  0.001405  0.001329 -0.001312  0.000964
#           8     0.001290  0.000784  0.002780  0.002022  0.002960  0.002741
#           12    0.001676  0.001271  0.002125  0.001345  0.002230  0.002705
#           16   -0.000129  0.000033 -0.000829  0.000530  0.000812 -0.002246
#           20    0.001086  0.000804  0.001386  0.002031  0.003173 -0.000857
# Saturday  0     0.001399  0.002094  0.005170  0.002574  0.003109  0.003265
#           4    -0.000431  0.000959  0.003874  0.001893  0.003947  0.002665
#           8    -0.000925 -0.000970  0.001369  0.001634  0.003059  0.000579
#           12    0.001135  0.001355  0.002393  0.001102  0.004728  0.000905
#           16    0.001420  0.002169  0.001210 -0.000803  0.003619  0.001580
#           20    0.000160  0.000996  0.001351 -0.000424 -0.000829  0.001496
# Sunday    0    -0.000348 -0.000156  0.000783  0.000273 -0.001108  0.000403
#           4     0.000433  0.000566  0.001777  0.001377  0.000883  0.000635
#           8     0.000532  0.000989  0.002086  0.002156 -0.001987  0.001215
#           12   -0.001288 -0.001030 -0.003172 -0.000742 -0.003537  0.000012
#           16   -0.000689  0.000264 -0.002391 -0.000263 -0.000521  0.000659
#           20    0.001245  0.002081  0.000094  0.001549 -0.002459 -0.001076
#
#                 MATICUSDT
# weekday   hour
# Monday    0     -0.005279
#           4     -0.002475
#           8     -0.000967
#           12     0.000285
#           16     0.001748
#           20     0.002282
# Tuesday   0      0.003287
#           4      0.001215
#           8      0.000861
#           12    -0.004221
#           16    -0.006470
#           20    -0.000078
# Wednesday 0      0.001374
#           4     -0.000419
#           8      0.001417
#           12    -0.000957
#           16    -0.003377
#           20     0.000752
# Thursday  0      0.001198
#           4      0.000541
#           8      0.001127
#           12     0.000527
#           16    -0.000369
#           20    -0.001676
# Friday    0      0.002605
#           4      0.002558
#           8     -0.000375
#           12    -0.001969
#           16    -0.001526
#           20     0.001913
# Saturday  0      0.003278
#           4      0.003371
#           8     -0.001845
#           12    -0.001829
#           16    -0.000894
#           20    -0.001116
# Sunday    0     -0.000116
#           4     -0.000172
#           8      0.002011
#           12     0.000202
#           16    -0.000292
#           20    -0.001410

# %%
interval_8h_sr = interval_8h_returns / interval_8h_std
interval_8h_sr
# Out:
#                  BTCUSDT   ETHUSDT   ADAUSDT   BNBUSDT   XRPUSDT   DOTUSDT  \
# weekday   hour
# Monday    0     0.007613 -0.035461 -0.047280 -0.062767 -0.101412 -0.184717
#           4     0.015495 -0.018972  0.008306 -0.037560 -0.035754 -0.125659
#           8     0.012098  0.045149 -0.010998  0.061311 -0.017383 -0.076365
#           12    0.090046  0.090569 -0.033276  0.048937  0.187947 -0.017711
#           16    0.129005  0.124765  0.071640  0.031571  0.312771  0.013387
#           20    0.116254  0.145779  0.082088  0.071334  0.258029  0.063158
# Tuesday   0     0.115767  0.097349  0.089428  0.113767  0.051855  0.073341
#           4     0.041609 -0.009886  0.104864  0.100752 -0.089349 -0.026813
#           8     0.094756  0.110180  0.106877  0.117058 -0.063003  0.022061
#           12   -0.032119 -0.063442 -0.067625 -0.012351 -0.104416 -0.133005
#           16   -0.045759 -0.088806 -0.090259 -0.057881  0.019894 -0.198307
#           20    0.084446  0.032815  0.030043  0.085301  0.105204 -0.059279
# Wednesday 0     0.078841  0.054975  0.040154  0.111506 -0.079597 -0.005097
#           4     0.056265  0.063193  0.049740  0.094504 -0.094871 -0.002999
#           8     0.127301  0.084655  0.109354  0.115966  0.040232  0.071117
#           12    0.124011  0.073070  0.043642  0.007799  0.069550 -0.010675
#           16    0.083994  0.096871  0.069394  0.017753  0.074139 -0.015043
#           20    0.059916  0.088666  0.087479  0.077266  0.081448  0.007255
# Thursday  0     0.006472  0.009170  0.025361 -0.003260  0.009664 -0.053991
#           4    -0.012647 -0.000481  0.046702  0.029861 -0.100733 -0.025405
#           8     0.023947  0.022958  0.039540  0.078703 -0.032036  0.022153
#           12    0.026914  0.047848 -0.008412  0.038597  0.055282 -0.043843
#           16    0.008499  0.050865 -0.003290 -0.045483  0.030689 -0.074392
#           20   -0.070207 -0.063532 -0.036838 -0.068084  0.049193 -0.091012
# Friday    0    -0.070244 -0.043326  0.018533  0.028843  0.057704  0.015368
#           4    -0.050591 -0.003194  0.043752  0.041990 -0.064218  0.040936
#           8     0.064718  0.031718  0.085536  0.070179  0.099785  0.098542
#           12    0.075880  0.051821  0.069297  0.050803  0.093310  0.106073
#           16   -0.005613  0.001206 -0.024416  0.018886  0.028145 -0.070436
#           20    0.059143  0.037102  0.048979  0.098375  0.126001 -0.031550
# Saturday  0     0.098853  0.119536  0.194888  0.126511  0.148895  0.131393
#           4    -0.032393  0.056391  0.141851  0.089068  0.199329  0.083789
#           8    -0.073674 -0.057730  0.050989  0.083923  0.141149  0.024963
#           12    0.094471  0.075008  0.089744  0.060232  0.166389  0.040619
#           16    0.102979  0.096586  0.043140 -0.037067  0.126961  0.063763
#           20    0.013424  0.051393  0.051219 -0.025754 -0.037939  0.063103
# Sunday    0    -0.023727 -0.007924  0.026383  0.013347 -0.045598  0.019616
#           4     0.030984  0.031776  0.065059  0.069516  0.050120  0.038135
#           8     0.036354  0.047341  0.074100  0.085804 -0.087068  0.062721
#           12   -0.094827 -0.044276 -0.121474 -0.029626 -0.157662  0.000549
#           16   -0.047003  0.011536 -0.093739 -0.012553 -0.022819  0.031536
#           20    0.072053  0.088443  0.003342  0.075565 -0.090759 -0.040969
#
#                 MATICUSDT
# weekday   hour
# Monday    0     -0.182484
#           4     -0.074544
#           8     -0.032819
#           12     0.009668
#           16     0.051342
#           20     0.083554
# Tuesday   0      0.110507
#           4      0.043821
#           8      0.037651
#           12    -0.150843
#           16    -0.213581
#           20    -0.002820
# Wednesday 0      0.060289
#           4     -0.016205
#           8      0.059240
#           12    -0.032874
#           16    -0.097547
#           20     0.019836
# Thursday  0      0.037421
#           4      0.018398
#           8      0.043293
#           12     0.016860
#           16    -0.009821
#           20    -0.059648
# Friday    0      0.080098
#           4      0.087783
#           8     -0.015130
#           12    -0.070555
#           16    -0.044697
#           20     0.069207
# Saturday  0      0.163034
#           4      0.119945
#           8     -0.076565
#           12    -0.081855
#           16    -0.036229
#           20    -0.046285
# Sunday    0     -0.006528
#           4     -0.010057
#           8      0.104327
#           12     0.009739
#           16    -0.014342
#           20    -0.052819

# %%
df_8h_returns[(df_8h_returns.index.weekday == 0) & (df_8h_returns.index.hour == 16)]["BTCUSDT"].cumsum().plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
interval_8h_returns["BTCUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday    hour
# Monday     16      0.003061
# Wednesday  12      0.002613
# Monday     20      0.002536
# Tuesday    0       0.002451
# Wednesday  8       0.002068
# Name: BTCUSDT, dtype: float64

# %%
interval_8h_sr["BTCUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday    hour
# Monday     16      0.129005
# Wednesday  8       0.127301
#            12      0.124011
# Monday     20      0.116254
# Tuesday    0       0.115767
# Name: BTCUSDT, dtype: float64

# %%
interval_8h_returns["ETHUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday    hour
# Monday     20      0.003906
#            16      0.003281
# Wednesday  20      0.002671
#            16      0.002527
# Monday     12      0.002413
# Name: ETHUSDT, dtype: float64

# %%
interval_8h_sr["ETHUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday   hour
# Monday    20      0.145779
#           16      0.124765
# Saturday  0       0.119536
# Tuesday   8       0.110180
#           0       0.097349
# Name: ETHUSDT, dtype: float64

# %%
interval_8h_returns["ADAUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday    hour
# Saturday   0       0.005170
#            4       0.003874
# Wednesday  20      0.003089
# Tuesday    4       0.003075
# Wednesday  8       0.002999
# Name: ADAUSDT, dtype: float64

# %%
interval_8h_sr["ADAUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday    hour
# Saturday   0       0.194888
#            4       0.141851
# Wednesday  8       0.109354
# Tuesday    8       0.106877
#            4       0.104864
# Name: ADAUSDT, dtype: float64

# %%
interval_8h_returns["BNBUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday    hour
# Tuesday    8       0.003138
# Wednesday  8       0.002990
#            4       0.002921
#            0       0.002838
# Tuesday    0       0.002729
# Name: BNBUSDT, dtype: float64

# %%
interval_8h_sr["BNBUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday    hour
# Saturday   0       0.126511
# Tuesday    8       0.117058
# Wednesday  8       0.115966
# Tuesday    0       0.113767
# Wednesday  0       0.111506
# Name: BNBUSDT, dtype: float64

# %%
interval_8h_returns["XRPUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday   hour
# Monday    16      0.010599
#           20      0.007432
#           12      0.005347
# Saturday  12      0.004728
#           4       0.003947
# Name: XRPUSDT, dtype: float64

# %%
interval_8h_sr["XRPUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday   hour
# Monday    16      0.312771
#           20      0.258029
# Saturday  4       0.199329
# Monday    12      0.187947
# Saturday  12      0.166389
# Name: XRPUSDT, dtype: float64

# %%
interval_8h_returns["DOTUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday   hour
# Saturday  0       0.003265
# Friday    8       0.002741
#           12      0.002705
# Saturday  4       0.002665
# Tuesday   0       0.002030
# Name: DOTUSDT, dtype: float64

# %%
interval_8h_sr["DOTUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday   hour
# Saturday  0       0.131393
# Friday    12      0.106073
#           8       0.098542
# Saturday  4       0.083789
# Tuesday   0       0.073341
# Name: DOTUSDT, dtype: float64

# %%
interval_8h_returns["MATICUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday   hour
# Saturday  4       0.003371
# Tuesday   0       0.003287
# Saturday  0       0.003278
# Friday    0       0.002605
#           4       0.002558
# Name: MATICUSDT, dtype: float64

# %%
interval_8h_sr["MATICUSDT"].sort_values(ascending=False).iloc[:5]
# Out:
# weekday   hour
# Saturday  0       0.163034
#           4       0.119945
# Tuesday   0       0.110507
# Sunday    8       0.104327
# Friday    4       0.087783
# Name: MATICUSDT, dtype: float64

# %%
import numpy as np
from datetime import timedelta

starting_cash = 100.0

sharpe_optimized_selections = {
    (0, 8): [{"action": "buy", "ticker": "BTCUSDT"}, {"action": "buy", "ticker": "XRPUSDT"}],
    (0, 12): [{"action": "buy", "ticker": "BTCUSDT"}],
    (0, 16): [{"action": "sell", "ticker": "BTCUSDT"}, {"action": "sell", "ticker": "XRPUSDT"}],
    (0, 20): [{"action": "sell", "ticker": "BTCUSDT"}],
    (4, 16): [
        {"action": "buy", "ticker": "ADAUSDT"},
        {"action": "buy", "ticker": "BNBUSDT"},
        {"action": "buy", "ticker": "DOTUSDT"},
        {"action": "buy", "ticker": "MATICUSDT"},
    ],
    (5, 0): [
        {"action": "sell", "ticker": "ADAUSDT"},
        {"action": "sell", "ticker": "BNBUSDT"},
        {"action": "sell", "ticker": "DOTUSDT"},
        {"action": "sell", "ticker": "MATICUSDT"},
    ],
}

trade_selections = {
    (0, 8): [{"action": "buy", "ticker": "BTCUSDT"}, {"action": "buy", "ticker": "XRPUSDT"}],
    (0, 12): [{"action": "buy", "ticker": "ETHUSDT"}],
    (0, 16): [{"action": "sell", "ticker": "BTCUSDT"}, {"action": "sell", "ticker": "XRPUSDT"}],
    (0, 20): [{"action": "sell", "ticker": "ETHUSDT"}],
    (1, 0): [{"action": "buy", "ticker": "BNBUSDT"}],
    (1, 8): [{"action": "sell", "ticker": "BNBUSDT"}],
    (2, 4): [{"action": "buy", "ticker": "BTCUSDT"}],
    (2, 8): [{"action": "buy", "ticker": "ETHUSDT"}],
    (2, 12): [{"action": "sell", "ticker": "BTCUSDT"}],
    (2, 16): [{"action": "sell", "ticker": "ETHUSDT"}],
    (4, 16): [{"action": "buy", "ticker": "ADAUSDT"}, {"action": "buy", "ticker": "DOTUSDT"}],
    (4, 20): [{"action": "buy", "ticker": "MATICUSDT"}],
    (5, 0): [{"action": "sell", "ticker": "ADAUSDT"}, {"action": "sell", "ticker": "DOTUSDT"}],
    (5, 4): [{"action": "sell", "ticker": "MATICUSDT"}],
}

######################### Delete this
# trade_selections = sharpe_optimized_selections
######################### Delete this

unique_stocks = set()
for action_list in trade_selections.values():
    for action_item in action_list:
        unique_stocks.add(action_item["ticker"])
num_unique_stocks = len(unique_stocks)

for time_pair in trade_selections:
    trades = trade_selections[time_pair]
    for trade in trades:
        if trade["action"] == "buy":
            trade["dollar_quantity"] = 2 * starting_cash / num_trades

strat_holdings_data = {
    'cash': [starting_cash],
    'BTCUSDT': [0.0],
    'ETHUSDT': [0.0],
    'ADAUSDT': [0.0],
    'BNBUSDT': [0.0],
    'XRPUSDT': [0.0],
    'DOTUSDT': [0.0],
    'MATICUSDT': [0.0],
}
has_coin_holding = False

held_tickers = set()

for time_index in px_close.index:
    for ticker in strat_holdings_data:
        strat_holdings_data[ticker].append(strat_holdings_data[ticker][-1])
    
    weekday = time_index.weekday()
    hour = time_index.hour
    
    backward_one_week = time_index - timedelta(weeks=1)
    forward_one_week = time_index + timedelta(weeks=1)
    
    for op in trade_selections.get((weekday, hour), []):
        action = op["action"]
        ticker = op["ticker"]
        
        if np.isnan(px_close.loc[time_index, ticker]):
            continue
        elif (forward_one_week in px_close.index) and \
            np.isnan(px_close.loc[forward_one_week, ticker]):
            continue
        elif (backward_one_week in px_close.index) and \
            np.isnan(px_close.loc[backward_one_week, ticker]):
            continue
        elif action == "buy":
            dollar_quantity = op["dollar_quantity"]
            num_shares = dollar_quantity / px_close.loc[time_index, ticker]
            
            strat_holdings_data[ticker][-1] += num_shares
            strat_holdings_data["cash"][-1] -= dollar_quantity
            held_tickers.add(ticker)
        elif action == "sell" and ticker in held_tickers:
            strat_holdings_data["cash"][-1] += px_close.loc[time_index, ticker] * strat_holdings_data[ticker][-1]
            strat_holdings_data[ticker][-1] = 0.0
            held_tickers.remove(ticker)

truncated_strat_holdings_data = {ticker: res[1:] for (ticker, res) in strat_holdings_data.items()}
strat_holdings_df = pd.DataFrame(truncated_strat_holdings_data, index=px_close.index)
strat_holdings_df.head(40)
# Out:
#                            cash   BTCUSDT   ETHUSDT     ADAUSDT   BNBUSDT  \
# datetime
# 2020-01-01 00:00:00  100.000000  0.000000  0.000000    0.000000  0.000000
# 2020-01-01 04:00:00   83.333333  0.002313  0.000000    0.000000  0.000000
# 2020-01-01 08:00:00   66.666667  0.002313  0.127382    0.000000  0.000000
# 2020-01-01 12:00:00   83.396988  0.000000  0.127382    0.000000  0.000000
# 2020-01-01 16:00:00  100.208871  0.000000  0.000000    0.000000  0.000000
# 2020-01-01 20:00:00  100.208871  0.000000  0.000000    0.000000  0.000000
# 2020-01-02 00:00:00  100.208871  0.000000  0.000000    0.000000  0.000000
# 2020-01-02 04:00:00  100.208871  0.000000  0.000000    0.000000  0.000000
# 2020-01-02 08:00:00  100.208871  0.000000  0.000000    0.000000  0.000000
# 2020-01-02 12:00:00  100.208871  0.000000  0.000000    0.000000  0.000000
# 2020-01-02 16:00:00  100.208871  0.000000  0.000000    0.000000  0.000000
# 2020-01-02 20:00:00  100.208871  0.000000  0.000000    0.000000  0.000000
# 2020-01-03 00:00:00  100.208871  0.000000  0.000000    0.000000  0.000000
# 2020-01-03 04:00:00  100.208871  0.000000  0.000000    0.000000  0.000000
# 2020-01-03 08:00:00  100.208871  0.000000  0.000000    0.000000  0.000000
# 2020-01-03 12:00:00  100.208871  0.000000  0.000000    0.000000  0.000000
# 2020-01-03 16:00:00   83.542204  0.000000  0.000000  487.186982  0.000000
# 2020-01-03 20:00:00   83.542204  0.000000  0.000000  487.186982  0.000000
# 2020-01-04 00:00:00  100.126049  0.000000  0.000000    0.000000  0.000000
# 2020-01-04 04:00:00  100.126049  0.000000  0.000000    0.000000  0.000000
# 2020-01-04 08:00:00  100.126049  0.000000  0.000000    0.000000  0.000000
# 2020-01-04 12:00:00  100.126049  0.000000  0.000000    0.000000  0.000000
# 2020-01-04 16:00:00  100.126049  0.000000  0.000000    0.000000  0.000000
# 2020-01-04 20:00:00  100.126049  0.000000  0.000000    0.000000  0.000000
# 2020-01-05 00:00:00  100.126049  0.000000  0.000000    0.000000  0.000000
# 2020-01-05 04:00:00  100.126049  0.000000  0.000000    0.000000  0.000000
# 2020-01-05 08:00:00  100.126049  0.000000  0.000000    0.000000  0.000000
# 2020-01-05 12:00:00  100.126049  0.000000  0.000000    0.000000  0.000000
# 2020-01-05 16:00:00  100.126049  0.000000  0.000000    0.000000  0.000000
# 2020-01-05 20:00:00  100.126049  0.000000  0.000000    0.000000  0.000000
# 2020-01-06 00:00:00  100.126049  0.000000  0.000000    0.000000  0.000000
# 2020-01-06 04:00:00  100.126049  0.000000  0.000000    0.000000  0.000000
# 2020-01-06 08:00:00   66.792715  0.002211  0.000000    0.000000  0.000000
# 2020-01-06 12:00:00   50.126049  0.002211  0.118759    0.000000  0.000000
# 2020-01-06 16:00:00   84.159128  0.000000  0.118759    0.000000  0.000000
# 2020-01-06 20:00:00  101.258078  0.000000  0.000000    0.000000  0.000000
# 2020-01-07 00:00:00   84.591412  0.000000  0.000000    0.000000  1.112907
# 2020-01-07 04:00:00   84.591412  0.000000  0.000000    0.000000  1.112907
# 2020-01-07 08:00:00  101.156136  0.000000  0.000000    0.000000  0.000000
# 2020-01-07 12:00:00  101.156136  0.000000  0.000000    0.000000  0.000000
#
#                        XRPUSDT  DOTUSDT  MATICUSDT
# datetime
# 2020-01-01 00:00:00   0.000000      0.0        0.0
# 2020-01-01 04:00:00   0.000000      0.0        0.0
# 2020-01-01 08:00:00   0.000000      0.0        0.0
# 2020-01-01 12:00:00   0.000000      0.0        0.0
# 2020-01-01 16:00:00   0.000000      0.0        0.0
# 2020-01-01 20:00:00   0.000000      0.0        0.0
# 2020-01-02 00:00:00   0.000000      0.0        0.0
# 2020-01-02 04:00:00   0.000000      0.0        0.0
# 2020-01-02 08:00:00   0.000000      0.0        0.0
# 2020-01-02 12:00:00   0.000000      0.0        0.0
# 2020-01-02 16:00:00   0.000000      0.0        0.0
# 2020-01-02 20:00:00   0.000000      0.0        0.0
# 2020-01-03 00:00:00   0.000000      0.0        0.0
# 2020-01-03 04:00:00   0.000000      0.0        0.0
# 2020-01-03 08:00:00   0.000000      0.0        0.0
# 2020-01-03 12:00:00   0.000000      0.0        0.0
# 2020-01-03 16:00:00   0.000000      0.0        0.0
# 2020-01-03 20:00:00   0.000000      0.0        0.0
# 2020-01-04 00:00:00   0.000000      0.0        0.0
# 2020-01-04 04:00:00   0.000000      0.0        0.0
# 2020-01-04 08:00:00   0.000000      0.0        0.0
# 2020-01-04 12:00:00   0.000000      0.0        0.0
# 2020-01-04 16:00:00   0.000000      0.0        0.0
# 2020-01-04 20:00:00   0.000000      0.0        0.0
# 2020-01-05 00:00:00   0.000000      0.0        0.0
# 2020-01-05 04:00:00   0.000000      0.0        0.0
# 2020-01-05 08:00:00   0.000000      0.0        0.0
# 2020-01-05 12:00:00   0.000000      0.0        0.0
# 2020-01-05 16:00:00   0.000000      0.0        0.0
# 2020-01-05 20:00:00   0.000000      0.0        0.0
# 2020-01-06 00:00:00   0.000000      0.0        0.0
# 2020-01-06 04:00:00   0.000000      0.0        0.0
# 2020-01-06 08:00:00  78.809659      0.0        0.0
# 2020-01-06 12:00:00  78.809659      0.0        0.0
# 2020-01-06 16:00:00   0.000000      0.0        0.0
# 2020-01-06 20:00:00   0.000000      0.0        0.0
# 2020-01-07 00:00:00   0.000000      0.0        0.0
# 2020-01-07 04:00:00   0.000000      0.0        0.0
# 2020-01-07 08:00:00   0.000000      0.0        0.0
# 2020-01-07 12:00:00   0.000000      0.0        0.0

# %%
def get_net_return(strat_holdings, ret):
    # assume that strat_holdings have already been shifted back in time to avoid look-ahead bias or that 
    # data does not depend on current time point
    gross_ret = (strat_holdings * ret).sum(axis=1)
    
    turnover = (strat_holdings.fillna(0) - strat_holdings.shift().fillna(0)).abs().sum(axis=1)
    tcost_bps = 20
    return gross_ret.subtract(turnover * tcost_bps * 1e-4, fill_value=0)

# %%
gross_returns = (strat_holdings_df * (px_close / px_close.shift() - 1)).sum(axis=1)
gross_returns.cumsum().plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
net_returns = get_net_return(strat_holdings_df, px_close / px_close.shift() - 1)
net_returns.cumsum().plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
net_returns.mean() / net_returns.std() * np.sqrt(365 * 6)
# Out:
# -0.748044405710275

# %%
import numpy as np

# (px_close * strat_holdings_df).head(40)
px_close_with_cash = px_close.join(pd.DataFrame(np.ones(len(px_close)), columns=["cash"], index=px_close.index))
px_close_with_cash
# Out:
#                       BTCUSDT  ETHUSDT  ADAUSDT   BNBUSDT  XRPUSDT  DOTUSDT  \
# datetime
# 2020-01-01 00:00:00   7230.71   130.18  0.03308   13.8159  0.19406      NaN
# 2020-01-01 04:00:00   7205.50   130.52  0.03320   13.7648  0.19518      NaN
# 2020-01-01 08:00:00   7195.80   130.84  0.03321   13.7162  0.19358      NaN
# 2020-01-01 12:00:00   7233.02   131.84  0.03357   13.7958  0.19428      NaN
# 2020-01-01 16:00:00   7223.72   131.98  0.03361   13.7270  0.19474      NaN
# ...                       ...      ...      ...       ...      ...      ...
# 2025-02-22 16:00:00  96644.39  2768.63  0.77880  675.6900  2.58720    5.102
# 2025-02-22 20:00:00  96579.75  2762.49  0.77380  667.5200  2.57580    5.052
# 2025-02-23 00:00:00  96493.46  2750.14  0.76880  665.6700  2.55310    5.045
# 2025-02-23 04:00:00  96492.75  2825.63  0.78510  665.6500  2.58960    5.082
# 2025-02-23 08:00:00  96386.69  2808.28  0.77790  660.7400  2.57420    5.054
#
#                      MATICUSDT  cash
# datetime
# 2020-01-01 00:00:00        NaN   1.0
# 2020-01-01 04:00:00        NaN   1.0
# 2020-01-01 08:00:00        NaN   1.0
# 2020-01-01 12:00:00        NaN   1.0
# 2020-01-01 16:00:00        NaN   1.0
# ...                        ...   ...
# 2025-02-22 16:00:00        NaN   1.0
# 2025-02-22 20:00:00        NaN   1.0
# 2025-02-23 00:00:00        NaN   1.0
# 2025-02-23 04:00:00        NaN   1.0
# 2025-02-23 08:00:00        NaN   1.0
#
# [11277 rows x 8 columns]

# %%
ret_with_cash = px_close_with_cash / px_close_with_cash.shift() - 1
# px_close_with_cash * strat_holdings_df
ret_with_cash
# Out:
#                       BTCUSDT   ETHUSDT   ADAUSDT   BNBUSDT   XRPUSDT  \
# datetime
# 2020-01-01 00:00:00       NaN       NaN       NaN       NaN       NaN
# 2020-01-01 04:00:00 -0.003487  0.002612  0.003628 -0.003699  0.005771
# 2020-01-01 08:00:00 -0.001346  0.002452  0.000301 -0.003531 -0.008198
# 2020-01-01 12:00:00  0.005172  0.007643  0.010840  0.005803  0.003616
# 2020-01-01 16:00:00 -0.001286  0.001062  0.001192 -0.004987  0.002368
# ...                       ...       ...       ...       ...       ...
# 2025-02-22 04:00:00  0.001059  0.003763  0.000655  0.005393  0.006774
# 2025-02-22 08:00:00  0.001100  0.018059  0.007728  0.002124  0.001199
# 2025-02-22 12:00:00  0.001087  0.013204  0.006369  0.002440  0.001622
# 2025-02-22 16:00:00 -0.000006 -0.000780  0.005812  0.027822 -0.002391
# 2025-02-22 20:00:00  0.000266 -0.000347 -0.001926 -0.010759 -0.001817
#
#                       DOTUSDT  MATICUSDT  cash
# datetime
# 2020-01-01 00:00:00       NaN        NaN   NaN
# 2020-01-01 04:00:00       NaN        NaN   0.0
# 2020-01-01 08:00:00       NaN        NaN   0.0
# 2020-01-01 12:00:00       NaN        NaN   0.0
# 2020-01-01 16:00:00       NaN        NaN   0.0
# ...                       ...        ...   ...
# 2025-02-22 04:00:00 -0.003116        NaN   0.0
# 2025-02-22 08:00:00 -0.007229        NaN   0.0
# 2025-02-22 12:00:00 -0.003543        NaN   0.0
# 2025-02-22 16:00:00  0.007703        NaN   0.0
# 2025-02-22 20:00:00 -0.009212        NaN   0.0
#
# [11274 rows x 8 columns]

# %%
gross_ret = (ret_with_cash * strat_holdings_df).head(40)
# Out:
#                      ADAUSDT  BNBUSDT   BTCUSDT  DOTUSDT  ETHUSDT  MATICUSDT  \
# datetime
# 2020-01-01 00:00:00      NaN      NaN       NaN      NaN      NaN        NaN
# 2020-01-01 04:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-01 08:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-01 12:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-01 16:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-01 20:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-02 00:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-02 04:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-02 08:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-02 12:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-02 16:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-02 20:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-03 00:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-03 04:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-03 08:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-03 12:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-03 16:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-03 20:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-04 00:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-04 04:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-04 08:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-04 12:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-04 16:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-04 20:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-05 00:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-05 04:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-05 08:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-05 12:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-05 16:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-05 20:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-06 00:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-06 04:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-06 08:00:00      NaN      NaN  0.000045      NaN      NaN        NaN
# 2020-01-06 12:00:00      NaN      NaN -0.000007      NaN      NaN        NaN
# 2020-01-06 16:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-06 20:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-07 00:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-07 04:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
# 2020-01-07 08:00:00      NaN      NaN  0.000000      NaN      NaN        NaN
# 2020-01-07 12:00:00      NaN      NaN -0.000000      NaN      NaN        NaN
#
#                      XRPUSDT  cash
# datetime
# 2020-01-01 00:00:00      NaN   NaN
# 2020-01-01 04:00:00      NaN   0.0
# 2020-01-01 08:00:00      NaN   0.0
# 2020-01-01 12:00:00      NaN   0.0
# 2020-01-01 16:00:00      NaN   0.0
# 2020-01-01 20:00:00      NaN   0.0
# 2020-01-02 00:00:00      NaN   0.0
# 2020-01-02 04:00:00      NaN   0.0
# 2020-01-02 08:00:00      NaN   0.0
# 2020-01-02 12:00:00      NaN   0.0
# 2020-01-02 16:00:00      NaN   0.0
# 2020-01-02 20:00:00      NaN   0.0
# 2020-01-03 00:00:00      NaN   0.0
# 2020-01-03 04:00:00      NaN   0.0
# 2020-01-03 08:00:00      NaN   0.0
# 2020-01-03 12:00:00      NaN   0.0
# 2020-01-03 16:00:00      NaN   0.0
# 2020-01-03 20:00:00      NaN   0.0
# 2020-01-04 00:00:00      NaN   0.0
# 2020-01-04 04:00:00      NaN   0.0
# 2020-01-04 08:00:00      NaN   0.0
# 2020-01-04 12:00:00      NaN   0.0
# 2020-01-04 16:00:00      NaN   0.0
# 2020-01-04 20:00:00      NaN   0.0
# 2020-01-05 00:00:00      NaN   0.0
# 2020-01-05 04:00:00      NaN   0.0
# 2020-01-05 08:00:00      NaN   0.0
# 2020-01-05 12:00:00      NaN   0.0
# 2020-01-05 16:00:00      NaN   0.0
# 2020-01-05 20:00:00      NaN   0.0
# 2020-01-06 00:00:00      NaN   0.0
# 2020-01-06 04:00:00      NaN   0.0
# 2020-01-06 08:00:00      NaN   0.0
# 2020-01-06 12:00:00      NaN   0.0
# 2020-01-06 16:00:00      NaN   0.0
# 2020-01-06 20:00:00      NaN   0.0
# 2020-01-07 00:00:00      NaN   0.0
# 2020-01-07 04:00:00      NaN   0.0
# 2020-01-07 08:00:00      NaN   0.0
# 2020-01-07 12:00:00      NaN   0.0

# %%
portfolio_ser = strat_holdings_df["BTCUSDT shares"] * px_close["BTCUSDT"] + strat_holdings_df["cash"]
portfolio_ser
# Out:
# datetime
# 2020-01-01 00:00:00    100.000000
# 2020-01-01 04:00:00    100.000000
# 2020-01-01 08:00:00    100.000000
# 2020-01-01 12:00:00    100.000000
# 2020-01-01 16:00:00    100.000000
#                           ...
# 2025-02-22 04:00:00    209.265353
# 2025-02-22 08:00:00    209.265353
# 2025-02-22 12:00:00    209.265353
# 2025-02-22 16:00:00    209.265353
# 2025-02-22 20:00:00    209.265353
# Length: 11274, dtype: float64

# %%
portfolio_returns = (portfolio_ser / portfolio_ser.shift() - 1)
portfolio_returns.cumsum().plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
portfolio_returns.mean() / portfolio_returns.std()
# Out:
# 0.018566874499773994

# %% [markdown]
# ###########################################################################

# %% [markdown]
# Week-to-week change in returns -- probably no pattern
