# %%
import numpy as np

X = np.random.randn(100, 2)
X
# Out:
# array([[ 2.48960276e+00, -6.78752026e-01],
#        [-4.48530834e-01, -2.97343310e-01],
#        [-4.52342146e-01,  8.97227187e-01],
#        [-3.80531215e-01, -8.21216079e-01],
#        [ 1.36361919e+00,  4.36145789e-01],
#        [-9.10378314e-01,  1.03317493e+00],
#        [ 1.18202891e-01,  5.63665405e-02],
#        [ 1.83846380e+00,  3.95994110e-01],
#        [-9.54520234e-01, -4.57375874e-01],
#        [ 9.47728735e-01, -4.60258187e-01],
#        [ 1.18242128e+00, -2.74394606e+00],
#        [-1.61095583e-01,  1.10777877e+00],
#        [ 5.85705870e-01,  1.43677519e-02],
#        [-4.25278508e-01,  1.11349507e-03],
#        [ 7.97470339e-01, -7.78523919e-01],
#        [ 6.96588598e-02, -7.95087543e-01],
#        [ 4.51345178e-01,  2.55812583e+00],
#        [ 6.58980760e-01, -8.36803802e-01],
#        [ 2.31187211e+00,  5.63146699e-03],
#        [-9.41021153e-01, -1.03578931e+00],
#        [-5.27466226e-01,  1.02828726e+00],
#        [ 5.70816861e-01, -4.88731281e-01],
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:,0], X[:,1])
